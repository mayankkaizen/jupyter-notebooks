# %% [markdown]
# <img src="images/plt.png" width="400" height="700"/>

# %% [markdown]
# ##### Tip
#
# Use `plt.cm?` to see availabe colorbars.
#
# Use `plt.rcParams['figure.figsize'] = (10, 7.5)` to change figure size
#
# `plt.axes(aspect = 'equal')` or `plt.axis(aspect='equal')` for length of x and y axis.

# %% [markdown]
# ### `rcParams`

# %%
plt.rcParams.find_all('/*')
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.avconv_args': [],
#           'animation.avconv_path': 'avconv',
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.html_args': [],
#           'animation.mencoder_args': [],
#           'animation.mencoder_path': 'mencoder',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'k',
#           'axes.facecolor': 'w',
#           'axes.formatter.limits': [-7, 7],
#           'axes.formatter.min_exponent': 0,
# ...

# %%
#save the defult rc parameters
IPython_default = plt.rcParams.copy()

#change some parameter
plt.rcParams['figure.figsize'] = (10, 7.5)

#if needed, revert to default values
plt.rcParams.update(IPython_default);

# %% [markdown]
# ### Stylesheets

# %%
# %pprint
plt.style.available
# Out:
# Pretty printing has been turned OFF
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', '_classic_test']

# %% [markdown]
# The basic way to switch to a stylesheet is to call
#
# ``` python
# plt.style.use('stylename')
# ```
#
# But keep in mind that this will change the style for the rest of the session!
# Alternatively, you can use the style context manager, which sets a style temporarily:
#
# ``` python
# with plt.style.context('stylename'):
#     make_a_plot()
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
x = np.linspace(0,10,100)

# %%
fig = plt.figure()
#matlab style
plt.style.use('seaborn-ticks')
plt.plot(x, np.sin(x),'-', label = 'sin')
plt.plot(x, np.cos(x), '--', label = 'cos')
plt.title('Sin and Cos Curve')
plt.ylabel('Y Axis')
plt.xlabel('X Axis')
plt.legend(loc = 'best')
plt.xlim(-2,12)
plt.ylim(-1.5,1.5)
plt.text(6.5,-1.3, 'test', color = 'yellow')
#plt.axis(xmin, xmax, ymin, ymax) can also be used above
plt.yticks(()) #there won't be any yaxis ticks
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %% [markdown]
# #### Ticks and Labels

# %% [markdown]
# `plt.xticks()` -> can set both locators and labels
# `ax.set_xticks()` -> can set only locators
# `ax.set_xticklabels()` -> set labels

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np

ax = plt.axes(xscale='log', yscale='log')

print(ax.xaxis.get_major_locator())
print(ax.xaxis.get_minor_locator())
print(ax.xaxis.get_major_formatter())
print(ax.xaxis.get_minor_formatter())

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np

ax = plt.axes()
ax.set_xticks(range(5))
ax.set_xticklabels(list('abcde'))
print(ax.xaxis.get_major_locator())
print(ax.xaxis.get_minor_locator())
print(ax.xaxis.get_major_formatter())
print(ax.xaxis.get_minor_formatter())

# %% [markdown]
# #### Summary of Formatters and Locators
#
# We've mentioned a couple of the available formatters and locators.
# We'll conclude this section by briefly listing all the built-in locator and formatter options. For more information on any of these, refer to the docstrings or to the Matplotlib online documentaion.
# Each of the following is available in the ``plt`` namespace:
#
# Locator class        | Description
# ---------------------|-------------
# ``NullLocator``      | No ticks
# ``FixedLocator``     | Tick locations are fixed
# ``IndexLocator``     | Locator for index plots (e.g., where x = range(len(y)))
# ``LinearLocator``    | Evenly spaced ticks from min to max
# ``LogLocator``       | Logarithmically ticks from min to max
# ``MultipleLocator``  | Ticks and range are a multiple of base
# ``MaxNLocator``      | Finds up to a max number of ticks at nice locations
# ``AutoLocator``      | (Default.) MaxNLocator with simple defaults.
# ``AutoMinorLocator`` | Locator for minor ticks
#
# Formatter Class       | Description
# ----------------------|---------------
# ``NullFormatter``     | No labels on the ticks
# ``IndexFormatter``    | Set the strings from a list of labels
# ``FixedFormatter``    | Set the strings manually for the labels
# ``FuncFormatter``     | User-defined function sets the labels
# ``FormatStrFormatter``| Use a format string for each value
# ``ScalarFormatter``   | (Default.) Formatter for scalar values
# ``LogFormatter``      | Default formatter for log axes
#
# We'll see further examples of these through the remainder of the book.

# %%
plt.plot(x, x + 0, '-g')  # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r');  # dotted red

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
x = np.linspace(0,10,100)
fig = plt.figure()
plt.style.use('seaborn')
#Python OO style
ax = plt.axes()
ax.plot(x, np.sin(x),'-', label = 'sin')
ax.plot(x, np.cos(x), '--', label = 'cos')
ax.legend(loc = 'best')
ax.text(6.2,-.25,'test')
#Note how following methods used in OO style. Compare them with Matlab style in above example
ax.set_ylabel('Y Axis')
ax.set_xlabel('X Axis')
ax.set_xlim(-2,12)
ax.set_ylim(-1.5,1.5)
ax.set_title('Sin and Cos Curve')
#alternatively ax.set(xlim=(0, 10), ylim=(-2, 2), xlabel='x', ylabel='sin(x)', title='A Simple Plot'); can be used 

ax.annotate('local maximum', xy=(1.57, 1), xytext=(4, 1.1),
            arrowprops=dict(facecolor='black', shrink=0.07))

ax.annotate('0 value', xy=(2*np.pi, 0), xytext=(8, -1.2),
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="angle3,angleA=0,angleB=-90"));
ax.set_yticks(()) #now there won't be any ticks
# Out:
# []

# %%
plt.xkcd()
fig = plt.figure()
ax=plt.axes()
ax.plot(x, x+1)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
x = np.linspace(0,10,100)
#fig = plt.figure()
fig, ax = plt.subplots(2, sharex = True)
ax[0].plot(x,np.sin(x), label = 'sin')
ax[0].legend()
ax[1].scatter(x, np.cos(x), label = 'cos', marker = '.')
ax[1].legend()
ax[0].set_title('sin curve')
ax[1].set_title('cos curve')
ax[0].set_ylim(-2,2)
#plt.legend() this only sets legend for last ax 
fig.suptitle('Sin & Cos Curve');

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
x = np.linspace(0,10,100)
#fig = plt.figure()
fig, ax = plt.subplots(2,2)
ax = ax.ravel()
a = range(4)
for c,d in zip(ax,a):
    c.plot(x**(d))

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0,10,100)
fig, ax = plt.subplots(2, 2)
for i, axi in enumerate(ax.flat):  #notice ax.flat
    axi.plot(x,(x**i))

# %%
fig.__class__
# Out:
# matplotlib.figure.Figure

# %%
ax.__class__
# Out:
# numpy.ndarray

# %% [markdown]
# In one of above examples, we have used `plt.axes`. This can also be used to create subplots manually like below

# %%
ax1 = plt.axes(aspect = 'equal')
ax2 = plt.axes([.5,.6,.2,.2]) 
#axes(rect, facecolor='w') 
#where *rect* = [left, bottom, width,height] in normalized (0, 1) units.  
#*facecolor* is the background color for the axis, default white.

# %%
# an interesting and more complete example
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')

cities = pd.read_csv('data/california_cities.csv')

# Extract the data we're interested in
lat, lon = cities['latd'], cities['longd']
population, area = cities['population_total'], cities['area_total_km2']

# Scatter the points, using size and color but no label
plt.scatter(lon, lat, label=None,
            c=np.log10(population), cmap='viridis',
            s=area, linewidth=0, alpha=0.5)
plt.axis(aspect='equal')
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.colorbar(label='log$_{10}$(population)')
plt.clim(3, 7)

# Here we create a legend:
# we'll plot empty lists with the desired size and label
for area in [100, 300, 500]:
    plt.scatter([], [], c='k', alpha=0.3, s=area,
                label=str(area) + ' km$^2$')
plt.legend(scatterpoints=1, frameon=False, labelspacing=1, title='City Area')

plt.title('California Cities: Area and Population');

# %% [markdown]
# ---
# #### Creating Legend by Hand
#
# From above example, we learn a way to create legend by hand which might be useful as in Matplotlib, scatterplots don't have any built-in way to show legends

# %%
for area in [100, 300, 500]:
    plt.scatter([], [], c='k', alpha=0.3, s=area,
                label=str(area) + ' km$^2$')
plt.legend(scatterpoints=1, frameon=False, labelspacing=1, title='City Area')

# %% [markdown]
# #### plot Versus scatter: A Note on Efficiency
#
# Aside from the different features available in ``plt.plot`` and ``plt.scatter``, why might you choose to use one over the other? While it doesn't matter as much for small amounts of data, as datasets get larger than a few thousand points, ``plt.plot`` can be noticeably more efficient than ``plt.scatter``. The reason is that ``plt.scatter`` has the capability to render a different size and/or color for each point, so the renderer must do the extra work of constructing each point individually. In ``plt.plot``, on the other hand, the points are always essentially clones of each other, so the work of determining the appearance of the points is done only once for the entire set of data. For large datasets, the difference between these two can lead to vastly different performance, and for this reason, ``plt.plot`` should be preferred over ``plt.scatter`` for large datasets.

# %%
import numpy as np
import matplotlib.pyplot as plt
n = 12
X = np.arange(n)
Y1 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)
Y2 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)
plt.axes([0.025, 0.025, 0.95, 0.95])
plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
plt.bar(X, -Y2, facecolor='#ff9999', edgecolor='white')
for x, y in zip(X, Y1):
    plt.text(x + 0.4, y + 0.05, '%.2f ' % y, ha='center', va= 'bottom')
for x, y in zip(X, Y2):
    plt.text(x + 0.4, -y - 0.05, '%.2f ' % y, ha='center', va= 'top')
plt.xlim(-.5, n)
plt.xticks(())
plt.ylim(-1.25,1.25)
plt.yticks(())
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)
plt.errorbar(x, y, yerr=dy, fmt='.k');

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
x = np.linspace(0,10,100)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(100)
fig = plt.figure()
plt.style.use('seaborn')
#Python OO style
ax = plt.axes()
ax.errorbar(x, y, yerr=dy, fmt='.k')
# Out:
# <Container object of 3 artists>

# %%
#not working and not understood

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
x = np.linspace(0,10,100)
ax = plt.axes()
ax.plot(x,x**3)
ax.plot(x,100*np.sin(x))
ax.fill_between(x,x**3, 100*np.sin(x),
                 color='gray', alpha=0.2)

# %%
ax = plt.axes()
ax.plot(x,x**2)
ax.plot(x, x**3)
ax.fill_between(x, x**2, x**3, color = 'gray') #first parameter will always be x.

# %%
import numpy as np
import matplotlib.pyplot as plt
n = 256
X = np.linspace(-np.pi, np.pi, n, endpoint=True)
Y = np.sin(2 * X)
plt.axes([0.025, 0.025, 0.95, 0.95])
plt.plot(X, Y + 1, color='blue', alpha=1.00)
plt.fill_between(X, 1, Y + 1, color='blue', alpha=.25)
plt.plot(X, Y - 1, color='blue', alpha=1.00)
plt.fill_between(X, -1, Y - 1, (Y - 1) > -1, color='blue', alpha=.25)
plt.fill_between(X, -1, Y - 1, (Y - 1) < -1, color='red', alpha=.25)
plt.xlim(-np.pi, np.pi)
plt.xticks(())
plt.ylim(-2.5, 2.5)
# Out:
# (-2.5, 2.5)

# %%
fig = plt.figure()
fig.add_axes([0,0,1,1])

# %%
fig = plt.figure()
ax1 = fig.add_subplot(121) #121 -> row,column,ax number
ax2= fig.add_subplot(122)
ax1.plot(x, np.sin(x))
ax2.plot(x,np.cos(x))
# or replace the first 3 lines from above with following line
#fig, (ax1,ax2) = plt.subplots(1,2)

# %%
fig, ax = plt.subplots(1,3)
ax[0].bar([1,2,3],[4,5,6])
ax[1].barh([.5,1,2.5],[0,1,2])
ax[1].axhline(0.5)
ax[0].axvline(0.5)
ax[2].scatter(x,x**2)

# %%
fig.suptitle("Super Title")
# Out:
# Text(0.5,0.98,'Super Title')

# %%
fig

# %%
x = np.linspace(0,10,100)
fig = plt.figure()
plt.plot(x,np.sin(x))
plt.arrow(2,0.0, .25, .25) #need better example

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)
plt.contour(X, Y, Z, colors='black');

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)
plt.contour(X, Y, Z, 20, cmap='RdGy')#20 means we need more linees- 20 equally spaced intervals within the data range
plt.colorbar()

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)
plt.contourf(X, Y, Z, 20, cmap='RdGy') #notice it is contourf, not contour
plt.colorbar()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-white')
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower', cmap='RdGy')
plt.colorbar()
plt.axis(aspect='image');

# %% [markdown]
# There are a few potential gotchas with ``imshow()``, however:
#
# - ``plt.imshow()`` doesn't accept an *x* and *y* grid, so you must manually specify the *extent* [*xmin*, *xmax*, *ymin*, *ymax*] of the image on the plot.
# - ``plt.imshow()`` by default follows the standard image array definition where the origin is in the upper left, not in the lower left as in most contour plots. This must be changed when showing gridded data.
# - ``plt.imshow()`` will automatically adjust the axis aspect ratio to match the input data; this can be changed by setting, for example, ``plt.axis(aspect='image')`` to make *x* and *y* units match.

# %%
contours = plt.contour(X, Y, Z, 3, colors='black')
plt.clabel(contours, inline=True, fontsize=8)

plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='RdGy', alpha=0.5)
plt.colorbar();

# %% [markdown]
# Finally, it can sometimes be useful to combine contour plots and image plots.
# For example, here we'll use a partially transparent background image (with transparency set via the ``alpha`` parameter) and overplot contours with labels on the contours themselves (using the ``plt.clabel()`` function)

# %%
#simple histogram
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

data = np.random.randn(1000)
plt.hist(data);

# %%
#above code with some parameter settings

plt.hist(data, bins=30, normed=True, alpha=0.5,
         histtype='stepfilled', color='steelblue',
         edgecolor='none');

# %%
#2D histogram

mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T

plt.hist2d(x, y, bins=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('counts in bin')

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
fig = plt.figure()
ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#3d contour plot

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
fig = plt.figure()
ax = plt.axes(projection='3d')

def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
X.ndim
# Out:
# 2

# %%
ax.view_init(60, 35)
fig

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_wireframe(X, Y, Z, color='black')
ax.set_title('wireframe');

# %%
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_title('surface');

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X ** 2 + Y ** 2)
Z = np.sin(R)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.cm.hot)
ax.contourf(X, Y, Z, zdir='z', offset=-2, cmap=plt.cm.hot)
ax.set_zlim(-2, 2)

# %% [markdown]
# ### Plotting a Vector Field : Quiver

# %%
import numpy as np
import matplotlib.pyplot as plt
n = 8
X, Y = np.mgrid[0:n, 0:n]
T = np.arctan2(Y - n / 2., X - n/2.)
R = 10 + np.sqrt((Y - n / 2.0) ** 2 + (X - n / 2.0) ** 2)
U, V = R * np.cos(T), R * np.sin(T)
plt.axes([0.025, 0.025, 0.95, 0.95])
plt.quiver(X, Y, U, V, R, alpha=.5)
plt.quiver(X, Y, U, V, edgecolor='k', facecolor='None', linewidth=.5)
plt.xlim(-1, n)
plt.xticks(())
plt.ylim(-1, n)
plt.yticks(())
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %% [markdown]
# ### Polar Plot

# %%
import numpy as np
import matplotlib.pyplot as plt
ax = plt.axes([0.025, 0.025, 0.95, 0.95], polar=True)
N = 20
theta = np.arange(0.0, 2 * np.pi, 2 * np.pi / N)
radii = 10 * np.random.rand(N)
width = np.pi / 4 * np.random.rand(N)
bars = plt.bar(theta, radii, width=width, bottom=0.0)
for r,bar in zip(radii, bars):
    bar.set_facecolor(plt.cm.jet(r/10.))
    bar.set_alpha(0.5)
    
ax.set_xticklabels([])
ax.set_yticklabels([])
# Out:
# []

# %%
import numpy as np
import matplotlib.pyplot as plt
eqs = []
eqs.append((r"$W^{3\beta}_{\delta_1 \rho_1 \sigma_2} = U^{3\beta}_{\delta_1 \rho_1} + \frac{1}{8 \pi 2} \int^{\alpha_2}_{\alpha_2} d \alpha^\prime_2 \left[\frac{ U^{2\beta}_{\delta_1\rho_1} - \alpha^\prime_2U^{1\beta}_{\rho_1 \sigma_2} }{U^{0\beta}_{\rho_1 \sigma_2}}\right]$"))
eqs.append((r"$\frac{d\rho}{d t} + \rho \vec{v}\cdot\nabla\vec{v} = -\nabla p + \mu\nabla^2␣,!\vec{v} + \rho \vec{g}$"))
eqs.append((r"$\int_{-\infty}^\infty e^{-x^2}dx=\sqrt{\pi}$"))
eqs.append((r"$E = mc^2 = \sqrt{{m_0}^2c^4 + p^2c^2}$"))
eqs.append((r"$F_G = G\frac{m_1m_2}{r^2}$"))
plt.axes([0.025, 0.025, 0.95, 0.95])
for i in range(24):
    index = np.random.randint(0, len(eqs))
    eq = eqs[index]
    size = np.random.uniform(12, 32)
    x,y = np.random.uniform(0, 1, 2)
    alpha = np.random.uniform(0.25, .75)
    plt.text(x, y, eq, ha='center', va='center', color="#11557c", alpha=alpha,transform=plt.gca().transAxes, fontsize=size, clip_on=True)
plt.xticks(())
plt.yticks(())
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
#https://stackoverflow.com/questions/38337918/plot-pie-chart-and-table-of-pandas-dataframe
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import table

# sample data
raw_data = {'officer_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
        'jan_arrests': [4, 24, 31, 2, 3],
        'feb_arrests': [25, 94, 57, 62, 70],
        'march_arrests': [5, 43, 23, 23, 51]}
df = pd.DataFrame(raw_data, columns = ['officer_name', 'jan_arrests', 'feb_arrests', 'march_arrests'])
df['total_arrests'] = df['jan_arrests'] + df['feb_arrests'] + df['march_arrests']

plt.figure(figsize=(16,8))
# plot chart
ax1 = plt.subplot(121, aspect='equal')
df.plot(kind='pie', y = 'total_arrests', ax=ax1, autopct='%1.1f%%', 
 startangle=90, shadow=False, labels=df['officer_name'], legend = False, fontsize=14)

# plot table
ax2 = plt.subplot(122)
plt.axis('off')
tbl = table(ax2, df, loc='center')
tbl.auto_set_font_size(True)
tbl.set_fontsize(14)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

data = [[66386, 174296, 75131, 577908, 32015],
        [58230, 381139, 78045, 99308, 160454],
       [89135, 80552, 152558, 497981, 603535],
       [78415, 81858, 150656, 193363, 69638],
       [139361, 331509, 343164, 781380, 52269]]

columns = ('Freeze', 'Wind', 'Flood', 'Quake', 'Hail')
rows =  ['%d year' % x for x in (100,50,20,10,5)]

values = np.arange(0,2500, 500)
value_increment = 1000

colors = plt.cm.BuPu(np.linspace(0,0.5, len(rows)))
n_rows = len(data)

index = np.arange(len(columns)) + 0.3
bar_width = 0.4

y_offset = np.zeros(len(columns))

# %%
colors, colors[::-1]
# Out:
# (array([[ 0.54901961,  0.58559016,  0.77517878,  1.        ],
#         [ 0.61877739,  0.73550173,  0.85397924,  1.        ],
#         [ 0.74800461,  0.82674356,  0.9015917 ,  1.        ],
#         [ 0.87792388,  0.92510573,  0.95664744,  1.        ],
#         [ 0.96862745,  0.98823529,  0.99215686,  1.        ]]),
#  array([[ 0.96862745,  0.98823529,  0.99215686,  1.        ],
#         [ 0.87792388,  0.92510573,  0.95664744,  1.        ],
#         [ 0.74800461,  0.82674356,  0.9015917 ,  1.        ],
#         [ 0.61877739,  0.73550173,  0.85397924,  1.        ],
#         [ 0.54901961,  0.58559016,  0.77517878,  1.        ]]))

# %%
cell_text = []
for row in range(n_rows):
    plt.bar(index, data[row], bar_width, bottom = y_offset, color = colors[row])
    y_offset = y_offset + data[row]
    cell_text.append(['%1.1f' %(x/1000.0) for x in y_offset])
    #colors = colors[::-1]
    cell_text.reverse()
    
the_table = plt.table(cellText = cell_text, rowLabels = rows, rowColours = colors, colLabels = columns, loc = 'bottom') 
plt.subplots_adjust(left=0.2, bottom = .2)

plt.ylabel("Loss in ${0}'s".format(value_increment))
plt.xticks([])
plt.yticks(values*value_increment, ['%d' % val for val in values])
plt.title('Loss by Disaster')
# Out:
# Text(0.5,1,'Loss by Disaster')

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

data = [[66386, 174296, 75131, 577908, 32015],
        [58230, 381139, 78045, 99308, 160454],
       [89135, 80552, 152558, 497981, 603535],
       [78415, 81858, 150656, 193363, 69638],
       [139361, 331509, 343164, 781380, 52269]]

columns = ('Freeze', 'Wind', 'Flood', 'Quake', 'Hail')
rows =  ['%d year' % x for x in (100,50,20,10,5)]

values = np.arange(0,2500, 500)
value_increment = 1000

colors = plt.cm.BuPu(np.linspace(0,0.5, len(rows)))
n_rows = len(data)

index = np.arange(len(columns)) + 0.3
bar_width = 0.4

y_offset = np.zeros(len(columns))

cell_text = []
for row in range(n_rows):
    plt.bar(index, data[row], bar_width, bottom = y_offset, color = colors[row])
    y_offset = y_offset + data[row]
    cell_text.append(['%1.1f' %(x/1000.0) for x in y_offset])
    colors = colors[::-1]
    cell_text.reverse()
    
the_table = plt.table(cellText = cell_text, rowLabels = rows, rowColours = colors, colLabels = columns, loc = 'bottom') 
plt.subplots_adjust(left=0.2, bottom = .2)

plt.ylabel("Loss in ${0}'s".format(value_increment))
plt.xticks([])
plt.yticks(values*value_increment, ['%d' % val for val in values])
plt.title('Loss by Disaster')
# Out:
# Text(0.5,1,'Loss by Disaster')

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

data = [[100, 125, 135, 145],
        [190, 250, 265, 285],
       [300, 370, 400, 430]]


columns = ('Sam', 'Mac', 'Peter', 'James')
rows =  ['%d year' % x for x in (1,2,3)]

colors = plt.cm.BuPu(np.linspace(0,0.5, len(rows)))
n_rows = len(data)

index = np.arange(len(columns)) + 0.3
bar_width = 0.4

y_offset = np.zeros(len(columns))

for row in range(n_rows):
    plt.bar(index, data[row], bar_width, bottom = y_offset, color = colors[row])
    y_offset = y_offset + data[row]
    cell_text.append(['%1.1f' %(x) for x in y_offset])
    
plt.xticks([])
plt.subplots_adjust(left=0.1, bottom = .1)

the_table = plt.table(cellText = data, rowLabels = rows, rowColours = colors, colLabels = columns, loc = 'bottom')

# %%
#example by Jake Vanderplas

data = pd.read_csv('c:/miniconda3/notebooks/Misc Toy Projects/internet.csv')
pivoted = data.pivot('year', 'country', 'users')
data.head()
# Out:
#      country  year     users
# 0  Argentina  1994  0.043706
# 1     Brazil  1994  0.037673
# 2     Canada  1994  2.378694
# 3      Chile  1994  0.141085
# 4      China  1994  0.001168

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
plt.style.use('ggplot')

plt.rcParams['figure.figsize'] = (10, 7.5)

# %%
pivoted.head()
# Out:
# country   Algeria  Argentina    Brazil     Canada     Chile     China  \
# year
# 1994     0.000361   0.043706  0.037673   2.378694  0.141085  0.001168
# 1995     0.001769   0.086277  0.105138   4.163525  0.346981  0.004955
# 1996     0.001739   0.141955  0.450789   6.760240  0.683476  0.013082
# 1997     0.010268   0.280340  0.786079  15.072357  1.057092  0.032395
# 1998     0.020239   0.830767  1.477875  24.897400  1.662322  0.168540
#
# country    France   Germany    Iceland     India     Israel     Italy  \
# year
# 1994     0.899867  0.922541   6.794812  0.001070   0.576966  0.192305
# 1995     1.637947  1.837738  11.215876  0.026229   0.930423  0.524413
# 1996     2.584034  3.054805  14.806479  0.046334   2.168368  1.023290
# 1997     4.255004  6.711087  27.478869  0.070768   4.399405  2.276738
# 1998     6.319779  9.877852  36.264207  0.139027  10.307070  4.558520
#
# country      Japan     Kenya    Mexico  New Zealand     Norway  South Africa  \
# year
# ...

# %%
pivoted.sum(0).sort_values().plot.barh(color='gray');

# %%
pivoted.plot.line();

# %%
sns.heatmap(pivoted.T);

# %%
sns.boxplot(x='year', y='users', color='steelblue', data=data);

# %%
pivoted.sum().plot.pie( autopct='%1.1f%%')

# %% [markdown]
# #### Matplotlib sometimes sucks and Seaborn offers elegant solution
#
# Below is the example which shows how scatterplot in Matplotlib sucks on at least three counts and how Seaborn solves all those three issues rather elegantly.
#
# - First Issue: Scatter plot in Matplotlib doesn't have any built-in method for creating legend as per `c` parameter
# - Second Issue: `c` parameter doesn't take list of string categorical values such as ['Yes', 'No']
# - Third Issue: This is subjective issue. The scatter plot in Matplotlib is ugly as compared to Seaborn
#
# See example below

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.rcParams['figure.figsize'] = (10, 7.5)

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.scatter(tips['total_bill'], tips['tip'], c = tips['smoker'], cmap = plt.cm.RdBu) # this is the second issue mentioned above
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\miniconda3\envs\data\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     131     try:
# --> 132         rgba = _colors_full_map.cache[c, alpha]
#     133     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# KeyError: ('No', None)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\miniconda3\envs\data\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4049                 # must be acceptable as PathCollection facecolors
# -> 4050                 colors = mcolors.to_rgba_array(c)
#    4051             except ValueError:
#
# ...

# %%
tips =  tips.replace(['Yes','No'], [1,0]) #work around for second issue
tips.head()
# Out:
#    total_bill   tip     sex  smoker  day    time  size
# 0       16.99  1.01  Female       0  Sun  Dinner     2
# 1       10.34  1.66    Male       0  Sun  Dinner     3
# 2       21.01  3.50    Male       0  Sun  Dinner     3
# 3       23.68  3.31    Male       0  Sun  Dinner     2
# 4       24.59  3.61  Female       0  Sun  Dinner     4

# %%
plt.scatter(tips['total_bill'], tips['tip'], c = tips['smoker'], cmap = plt.cm.RdBu)#no direct way to show legend to show what those color means

# %%
# Here comes the Seaborn

sns.relplot(x = "total_bill", y = "tip",hue = 'smoker', data = tips);

# %% [markdown]
# The Seaborn plot is far more beautiful than that of Matplotlib. And a bonus point here is that Seaborn automatically added labels to both axes.
#
# However I tried many ways to change the size of this plot but couldn't succeed. I tried
#
# `fig = plt.figure(figsize = (10,7.5)`
#
# and
#
# `plt.rcParams['figure.figsize'] = (10, 7.5)`
#
# and
#
# `sns.set(rc = {'figure.figsize' = (10,7.5)})`
#
# but nothing worked.
#
# Finally I tried setting the `height parameter` in `sns.relplot` function which did the trick.

# %% [markdown]
# ### Seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", data=tips, height  =  7);

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", style="time", data=tips, height = 7 );

# %%
sns.relplot(x="total_bill", y="tip", hue="size", data=tips, height = 7);

# %%
sns.relplot(x="total_bill", y="tip", hue="size", palette="ch:r=-.5,l=.75", data=tips, height = 7)

# %%
sns.relplot(x="total_bill", y="tip", size="size", data=tips, height = 7);

# %%
sns.relplot(x="total_bill", y="tip", size="size", sizes=(15, 200), data=tips, height = 7);

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker",
            col="time", data=tips);

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %% [markdown]
# #### Aggregation and representing uncertainty
#
# More complex datasets will have multiple measurements for the same value of the x variable. The default behavior in seaborn is to aggregate the multiple measurements at each x value by plotting the mean and the 95% confidence interval around the mean:

# %%
sns.relplot(x="timepoint", y="signal", kind="line", data=fmri, height = 7);

# %% [markdown]
# Another good option, especially with larger data, is to represent the spread of the distribution at each timepoint by plotting the standard deviation instead of a confidence interval:

# %%
sns.relplot(x="timepoint", y="signal", kind="line", ci="sd", data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", hue="event", kind="line", data=fmri, height = 7);

# %%
sns.relplot(x="timepoint", y="signal", hue="region", style="event",
            kind="line", data=fmri, height = 7);

# %%
sns.relplot(x="timepoint", y="signal", hue="region", style="event",
            dashes=False, markers=True, kind="line", data=fmri, height = 7);

# %%
sns.relplot(x="timepoint", y="signal", hue="subject",
            col="region", row="event", height=4,
            kind="line", estimator=None, data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", hue="event", style="event",
            col="subject", col_wrap=5,
            height=3, aspect=.75, linewidth=2.5,
            kind="line", data=fmri.query("region == 'frontal'"));

# %% [markdown]
# #### Histogram, KDE, Box Plot and Normal Distribution

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.mlab as mlab
import seaborn as sns
sns.set()

mu = 0  #mean
sigma = 1 #std
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x,mlab.normpdf(x, mu, sigma));

# %%
#alternative way. also preferred way

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import norm
sns.set()

x = np.linspace(-5,5,100)
plt.plot(x, norm.pdf(x, loc = 0, scale = 1), '-',color = 'red', label = 'mean 0 var 1')
plt.plot(x, norm.pdf(x, loc = .5, scale = 2), '-',color = 'blue', label = 'mean .5 var 2')
plt.legend();

# %%
x = np.random.randn(500)
plt.plot(x,'.');

# %%
plt.hist(x, bins = 25);

# %%
sns.kdeplot(x, shade = True);

# %%
sns.rugplot(x);

# %%
sns.distplot(x, kde = True, rug = True, color = 'red');

# %%
x = np.array([-2.1, -1.3, -0.4,  1.9,  5.1,  6.2])
x
# Out:
# array([-2.1, -1.3, -0.4,  1.9,  5.1,  6.2])

# %%
plt.boxplot(x);
a = np.min(x)
b = np.max(x)
c = np.median(x)
e = np.percentile(x, 75)
f = np.percentile(x, 25)

plt.hlines(a, 0,.9, colors = 'r', linestyles = '--', label = 'min value')
plt.hlines(b, 0,.9, colors = 'yellow', linestyles = '--', label = 'max value')
plt.hlines(c, 0,.9, colors = 'green', linestyles = '--', label = 'median value')
plt.hlines(e, 0,.9, colors = 'cyan', linestyles = '--', label = '75 quantile')
plt.hlines(f, 0,.9, colors = 'blue', linestyles = '--', label = '25 quantile')
plt.legend();

# %% [markdown]
# Earlier x was `array([-2.1, -1.3, -0.4,  1.9,  5.1,  6.2])`. When we plotted box plot for this, we didn't see any representation for outliers in data as there was no outlier in our data.
#
# Let us change our data a bit -

# %%
x = np.array([-2.1, -1.3, -0.4,  1.9,  5.1,  16.2])   #16.2 is outlier here.

plt.boxplot(x);
a = np.min(x)
b = np.max(x)
c = np.median(x)
e = np.percentile(x, 75)
f = np.percentile(x, 25)

plt.hlines(a, 0,.9, colors = 'r', linestyles = '--', label = 'min value')
plt.hlines(b, 0,.9, colors = 'yellow', linestyles = '--', label = 'max value')
plt.hlines(c, 0,.9, colors = 'green', linestyles = '--', label = 'median value')
plt.hlines(e, 0,.9, colors = 'cyan', linestyles = '--', label = '75 quantile')
plt.hlines(f, 0,.9, colors = 'blue', linestyles = '--', label = '25 quantile')
plt.legend();

# %%
hex(0), hex(127), hex(128), hex(200)
# Out:
# ('0x0', '0x7f', '0x80', '0xc8')

# %%
int('0x7ff',16)
# Out:
# 2047

# %%
2047-128
# Out:
# 1919

# %%
bin(127), bin(128)
# Out:
# ('0b1111111', '0b10000000')

# %%
bin(2047)
# Out:
# '0b11111111111'

# %%
ord('\u0081') #code point to code point value coversion
# Out:
# 129

# %%
chr(200) #returns unicode string
# Out:
# 'È'

# %%
print('\u0081'), print('\u0077') #printing unicode
# Out:
# 
# w
# (None, None)

# %%
ord('w')
# Out:
# 119

# %%
chr(200).encode() #opposite method is bytes.decode
# Out:
# b'\xc3\x88'

# %%
b'\xc3\x88'.decode() #opposite method is str.encode as shown above
# Out:
# 'È'

# %% [markdown]
# Unicode -
#
# Every character has a code point and code point value. Code point value is simply its position in Unicode table. Each character may take 1 to 4 bytes for storage. Code points are represented by hex values of code point value.
#
#
#  - If the code point is < 128, it’s represented by the corresponding byte value.
#  - If the code point is >= 128, it’s turned into a sequence of two, three, or four bytes, where each byte of the sequence is between 128 and 255.
#
#
# For example, let us consider the character 'w'.

# %%
ord('w'), ord('\x77') # character or code point to code point value conversion
# Out:
# (119, 119)

# %%
chr(119), chr(0x77) # code point value (decimal or hex) to character
# Out:
# ('w', 'w')

# %%
print(u'77')
# Out:
# 77

# %%
chr(131) #non printable character hence returned its code point
# Out:
# '\x83'

# %%
print('\x83') #proof that character with code point 131 (or code point '\x83') is non printable character
# Out:
# 

# %%
ord('\x83') # code point value
# Out:
# 131

# %%
hex(131), hex(119) #hex value
# Out:
# ('0x83', '0x77')

# %%
'\x83'.encode() #string to byte conversion. This  is how string is stored.
# Out:
# b'\xc2\x83'

# %%
b'\xc2\x83'.decode() #byte to string coversion
# Out:
# '\x83'

# %%
bin(0xc2), bin(0x83) #this is how character with code point value 131 ('\x83') is stored in 2 bytes
# Out:
# ('0b11000010', '0b10000011')

# %%
bin(0x0), bin(0x7f) # first and last character for one byte storage. This is ASCII range (127 characters)
# Out:
# ('0b0', '0b1111111')

# %%
bin(0x80), '\x80'.encode() #first character to take 2 bytes
# Out:
# ('0b10000000', b'\xc2\x80')

# %%
bin(0x7ff), '\x7ff'.encode(), b'\x7ff'.decode() #last character which can be stored in 2 bytes under UTF-8
# Out:
# ('0b11111111111', b'\x7ff', '\x7ff')

# %%
'w'.encode()
# Out:
# b'w'

# %%
b'w'.decode()
# Out:
# 'w'

# %%
bin(10)
# Out:
# '0b1010'
