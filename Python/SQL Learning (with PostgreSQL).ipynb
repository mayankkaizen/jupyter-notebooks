# %% [markdown]
# You can connect to a database and issue SQL commands inside Jupyter Notebook. For this module `ipython-sql` needs to be installed via `pip`. Once installed, load it by using `%load_ext sql` magic command as shown below. Then one can issue SQL commands after using `%sql` for single line SQL command or `%%sql` for multi-line SQL commands. See below for examples.
#
# For issuing PostgreSQL meta commands, we need to install 'pgspecial' via pip. (Not clear how to use it.)

# %%
# %load_ext sql

import numpy as np
import pandas as pd

# %%
# %%sql
#
# postgres://postgres:xyzaaa@localhost/postgres
# Out:
# 'Connected: postgres@postgres'

# %%
# %%sql
# SELECT * FROM dft;
# Out:
#  * postgres://postgres:***@localhost/postgres
# (psycopg2.ProgrammingError) relation "dft" does not exist
# LINE 1: SELECT * FROM dft;
#                       ^
#  [SQL: 'SELECT * FROM dft;'] (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %sql data << SELECT * from cities; --o/p of query can be assigned to a local variable
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# Returning data to local variable data

# %%
data
# Out:
# [('San Francisco', '(-194,53)')]

# %%
import pgspecial

# %%
df1 = data.DataFrame() ##save the query result to a dataframe
df1
# Out:
#             name   location
# 0  San Francisco  (-194,53)

# %%
# %sql \d #not working
# Out:
#  * postgres://postgres:***@localhost/postgres
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-abfe5fef5d81> in <module>
# ----> 1 get_ipython().run_line_magic('sql', '\\d #not working')
#
# ~\Miniconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2285                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2286             with self.builtin_trap:
# -> 2287                 result = fn(*args,**kwargs)
#    2288             return result
#    2289
#
# <decorator-gen-127> in execute(self, line, cell, local_ns)
#
# ~\Miniconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# <decorator-gen-126> in execute(self, line, cell, local_ns)
#
# ~\Miniconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\Miniconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# ~\Miniconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     335                 _, cur, headers, _ = pgspecial.execute(
#     336                     conn.session.connection.cursor(), statement)[0]
# --> 337                 result = FakeResultProxy(cur, headers)
#     338             else:
#     339                 txt = sqlalchemy.sql.text(statement)
#
# ~\Miniconda3\lib\site-packages\sql\run.py in __init__(self, cursor, headers)
#     298
#     299     def __init__(self, cursor, headers):
# --> 300         self.fetchall = cursor.fetchall
#     301         self.fetchmany = cursor.fetchmany
#     302         self.rowcount = cursor.rowcount
#
# AttributeError: 'NoneType' object has no attribute 'fetchall'

# %%
# %sql DROP TABLE df1;
# %sql PERSIST df1 #PERSIST is ipython-sql specific PSEUDO-SQL command to save dataframe into a same-name database table
# %sql SELECT * FROM df1;
# Out:
#  * postgres://postgres:***@localhost/postgres
# (psycopg2.ProgrammingError) table "df1" does not exist
#  [SQL: 'DROP TABLE df1;'] (Background on this error at: http://sqlalche.me/e/f405)
#  * postgres://postgres:***@localhost/postgres
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(0, 'San Francisco', '(-194,53)')]

# %% [markdown]
# ### SQL

# %%
# %%sql
#
# CREATE TABLE mydata (
# id INTEGER,
#     language VARCHAR(20),
#     author VARCHAR(25),
#     year INTEGER);
# Out:
#  * postgres://postgres:***@localhost/postgres
# Done.
# []

# %%
# %%sql
# INSERT INTO mydata VALUES (1, 'Fortran', 'Backus', 1955), (2, 'Lisp' , 'McCarthy', 1958);
# INSERT INTO mydata (id, author, language, year) VALUES (3, 'Hopper', 'Cobol', 1959);
# SELECT * FROM mydata;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 2 rows affected.
# 1 rows affected.
# 3 rows affected.
# [(1, 'Fortran', 'Backus', 1955),
#  (2, 'Lisp', 'McCarthy', 1958),
#  (3, 'Cobol', 'Hopper', 1959)]

# %% [markdown]
# Notice how multiple records were inserted without mentioning column types (because order was implicitly assumed). Also notice how third record was inserted. Here order of fields is different from default order.
#
# #### Constraints

# %%
# %%sql
#
# CREATE TABLE mydatacopy (
# id INTEGER NOT NULL,
# language VARCHAR(20) NOT NULL,
# author VARCHAR(25) NOT NULL,
# year INTEGER NOT NULL,
# standard VARCHAR(20) NULL);
#
# INSERT INTO mydatacopy (id, language, author, year, standard) VALUES (1, 'prolog', 'Colmerauer', '1972', 'ISO');
# INSERT INTO mydatacopy (id, language, author, year) VALUES (2, 'Perl', 'Wall', '1987');
# INSERT INTO mydatacopy (id, year, standard,language, author) VALUES (3, '1964', 'ANSI', 'APL', 'Iverson');
#
# SELECT * FROM mydatacopy; --this is how write comment
# Out:
#  * postgres://postgres:***@localhost/postgres
# Done.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 3 rows affected.
# [(1, 'prolog', 'Colmerauer', 1972, 'ISO'),
#  (2, 'Perl', 'Wall', 1987, None),
#  (3, 'APL', 'Iverson', 1964, 'ANSI')]

# %%
# %sql SELECT * FROM mydatacopy WHERE standard is Null;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(2, 'Perl', 'Wall', 1987, None)]

# %%
# %sql SELECT * FROM mydatacopy WHERE standard = Null; --compare this with above query
# Out:
#  * postgres://postgres:***@localhost/postgres
# 0 rows affected.
# []

# %% [markdown]
# #### Primary Key Constraint
#
# A primary key constraint indicates that a column, or group of columns, can be used as a unique identifier for rows in the table. This requires that the values be both unique and not null. So, the following two table definitions accept the same data:
# ```
# CREATE TABLE products (
# product_no integer UNIQUE NOT NULL,
# name text,
# price numeric
# );
# ```
# ```
# CREATE TABLE products (
# product_no integer PRIMARY KEY,
# name text,
# price numeric
# );
# ```
# **Primary keys can span more than one column**; the syntax is similar to unique constraints:
# ```
# CREATE TABLE example (
# a integer,
# b integer,
# c integer,
# PRIMARY KEY (a, c)
# );
# ```
# Adding a primary key will automatically create a unique B-tree index on the column or group of columns listed in the primary key, and will force the column(s) to be marked `NOT NULL`.
#
# **A table can have at most one primary key.** (There can be any number of unique and not-null constraints, which are functionally almost the same thing, but only one can be identified as the primary key.)

# %%
# %%sql
#
# CREATE TABLE mydatacopy2 (
# id INTEGER NOT NULL PRIMARY KEY,
# language VARCHAR(20) NOT NULL,
# author VARCHAR(25) NOT NULL,
# year INTEGER NOT NULL,
# standard VARCHAR(20) NULL);
# Out:
#  * postgres://postgres:***@localhost/postgres
# Done.
# []

# %% [markdown]
# #### Unique Key Constraint

# %%
# %%sql
#
# CREATE TABLE mydatacopy3 (
# id INTEGER NOT NULL PRIMARY KEY,
# language VARCHAR(20) NOT NULL UNIQUE,
# author VARCHAR(25) NOT NULL,
# year INTEGER NOT NULL,
# standard VARCHAR(20) NULL);
#
#
# INSERT INTO mydatacopy3 (id, language, author, year, standard) VALUES (1, 'prolog', 'Colmerauer', '1972', 'ISO');
# INSERT INTO mydatacopy3 (id, language, author, year) VALUES (2, 'Perl', 'Wall', '1987');
# INSERT INTO mydatacopy3 (id, year, standard,language, author) VALUES (3, '1964', 'ANSI', 'APL', 'Iverson');
# INSERT INTO mydatacopy3 (id, year, standard,language, author) VALUES (3, '1964', 'ANSI', 'APL', 'Iverson');
# -- Last record will not be inserted a
# SELECT * FROM mydatacopy3;
# Out:
#  * postgres://postgres:***@localhost/postgres
# Done.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#
# IntegrityError: duplicate key value violates unique constraint "mydatacopy3_pkey"
# DETAIL:  Key (id)=(3) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-63-805cc1950610> in <module>()
# ----> 1 get_ipython().run_cell_magic('sql', '', "\nCREATE TABLE mydatacopy3 (\nid INTEGER NOT NULL PRIMARY KEY,\nlanguage VARCHAR(20) NOT NULL UNIQUE,\nauthor VARCHAR(25) NOT NULL,\nyear INTEGER NOT NULL,\nstandard VARCHAR(20) NULL);\n\n\nINSERT INTO mydatacopy3 (id, language, author, year, standard) VALUES (1, 'prolog', 'Colmerauer', '1972', 'ISO');\nINSERT INTO mydatacopy3 (id, language, author, year) VALUES (2, 'Perl', 'Wall', '1987');\nINSERT INTO mydatacopy3 (id, year, standard,language, author) VALUES (3, '1964', 'ANSI', 'APL', 'Iverson');\nINSERT INTO mydatacopy3 (id, year, standard,language, author) VALUES (3, '1964', 'ANSI', 'APL', 'Iverson');\n \nSELECT * FROM mydatacopy3; ")
#
# C:\miniconda3\envs\data\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2101             magic_arg_s = self.var_expand(line, stack_depth)
#    2102             with self.builtin_trap:
# -> 2103                 result = fn(magic_arg_s, cell)
#    2104             return result
#    2105
#
# <decorator-gen-127> in execute(self, line, cell, local_ns)
#
# C:\miniconda3\envs\data\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# <decorator-gen-126> in execute(self, line, cell, local_ns)
#
# C:\miniconda3\envs\data\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\miniconda3\envs\data\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# C:\miniconda3\envs\data\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     338             else:
#     339                 txt = sqlalchemy.sql.text(statement)
# --> 340                 result = conn.session.execute(txt, user_namespace)
#     341             _commit(conn=conn, config=config)
#     342             if result and config.feedback:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object, *multiparams, **params)
#     946             raise exc.ObjectNotExecutableError(object)
#     947         else:
# --> 948             return meth(self, multiparams, params)
#     949
#     950     def _execute_function(self, func, multiparams, params):
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     267     def _execute_on_connection(self, connection, multiparams, params):
#     268         if self.supports_execution:
# --> 269             return connection._execute_clauseelement(self, multiparams, params)
#     270         else:
#     271             raise exc.ObjectNotExecutableError(self)
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1058             compiled_sql,
#    1059             distilled_params,
# -> 1060             compiled_sql, distilled_params
#    1061         )
#    1062         if self._has_events or self.engine._has_events:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1191                         statement,
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#    1195             self._handle_dbapi_exception(
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     505
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#     509     def do_execute_no_params(self, cursor, statement, context=None):
#
# IntegrityError: (psycopg2.IntegrityError) duplicate key value violates unique constraint "mydatacopy3_pkey"
# DETAIL:  Key (id)=(3) already exists.
#  [SQL: "INSERT INTO mydatacopy3 (id, year, standard,language, author) VALUES (3, '1964', 'ANSI', 'APL', 'Iverson');"] (Background on this error at: http://sqlalche.me/e/gkpj)

# %%
# %sql SELECT * FROM mydatacopy3;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 3 rows affected.
# [(1, 'prolog', 'Colmerauer', 1972, 'ISO'),
#  (2, 'Perl', 'Wall', 1987, None),
#  (3, 'APL', 'Iverson', 1964, 'ANSI')]

# %% [markdown]
# #### Unique key constraint
#
# A unique key like a primary key is also used to make each record inside a table unique. Once you have defined the primary key of a table, any other fields yomu wish to make unique is done through this constraint. For example, in our database it now makes sense to have a unique key constraint on the language field. This would
# ensure none of the records would duplicate information about the same programming language.

# %% [markdown]
# #### Creating New Table from Existing Table

# %%
# %%sql
#
# CREATE TABLE mydata4 AS SELECT * FROM mydatacopy3;
# SELECT * FROM mydata4;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 3 rows affected.
# 3 rows affected.
# [(1, 'prolog', 'Colmerauer', 1972, 'ISO'),
#  (2, 'Perl', 'Wall', 1987, None),
#  (3, 'APL', 'Iverson', 1964, 'ANSI')]

# %% [markdown]
# #### Writing Some Basic Queries

# %%
# %sql SELECT language, author FROM mydata4;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 3 rows affected.
# [('prolog', 'Colmerauer'), ('Perl', 'Wall'), ('APL', 'Iverson')]

# %%
# %sql SELECT language, year FROM mydata4 ORDER BY year;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 3 rows affected.
# [('APL', 1964), ('prolog', 1972), ('Perl', 1987)]

# %%
# %sql SELECT language, author FROM mydata4 ORDER BY 2 DESC; -- 1 means language, 2 means author
# Out:
#  * postgres://postgres:***@localhost/postgres
# 3 rows affected.
# [('Perl', 'Wall'), ('APL', 'Iverson'), ('prolog', 'Colmerauer')]

# %%
# %sql SELECT language, standard FROM mydata4 WHERE standard = 'ANSI';
# Out:
#    postgres://postgres:***@localhost/exercises
#  * postgres://postgres:***@localhost/postgres
# 3 rows affected.
# [('APL', 'ANSI'), ('Fortran', 'ANSI'), ('Fortran', 'ANSI')]

# %%
# %sql SELECT language, author FROM mydata4 WHERE YEAR > 1970 ORDER BY language;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 2 rows affected.
# [('Perl', 'Wall'), ('prolog', 'Colmerauer')]

# %%
# %sql SELECT language, year, standard FROM mydata4 WHERE YEAR > 1970 AND standard is Null;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [('Perl', 1987, None)]

# %%
# %sql SELECT language, author FROM mydata4 WHERE year BETWEEN 1980 AND 1990;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [('Perl', 'Wall')]

# %%
# %sql SELECT language, author FROM mydata4 WHERE year NOT BETWEEN 1980 AND 1990;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 2 rows affected.
# [('prolog', 'Colmerauer'), ('APL', 'Iverson')]

# %% [markdown]
# ##### Inserting Null

# %%
# %%sql
#
# INSERT INTO mydata4 VALUES (4, 'Tcl', 'Ousterhout', '1988', NULL);
# SELECT * from mydata4;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# 4 rows affected.
# [(1, 'prolog', 'Colmerauer', 1972, 'ISO'),
#  (2, 'Perl', 'Wall', 1987, None),
#  (3, 'APL', 'Iverson', 1964, 'ANSI'),
#  (4, 'Tcl', 'Ousterhout', 1988, None)]

# %% [markdown]
# ##### Inserting Data into a Table from Another Table

# %%
# %sql DROP TABLE mydata, mydatacopy, mydatacopy2;
# Out:
#  * postgres://postgres:***@localhost/postgres
# Done.
# []

# %% [markdown]
# ##### Updating/Deleting Records

# %%
# %%sql
#
# CREATE TABLE mydata (language VARCHAR(20), standard VARCHAR(10));
# INSERT INTO mydata SELECT language, standard FROM mydata4 WHERE standard IS NOT NULL;
# SELECT * FROM mydata;
# Out:
#  * postgres://postgres:***@localhost/postgres
# Done.
# 2 rows affected.
# 2 rows affected.
# [('prolog', 'ISO'), ('APL', 'ANSI')]

# %%
# %%sql
#
# INSERT INTO mydata4 VALUES (4, 'Forth', 'Moore');
# SELECT * FROM mydata4;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# 5 rows affected.
# [(1, 'prolog', 'Colmerauer', 1972, 'ISO'),
#  (2, 'Perl', 'Wall', 1987, None),
#  (3, 'APL', 'Iverson', 1964, 'ANSI'),
#  (4, 'Tcl', 'Ousterhout', 1988, None),
#  (4, 'Forth', 'Moore', None, None)]

# %%
# %%sql
#
# UPDATE mydata4 SET year = 1972, standard = 'ANSI' WHERE language  = 'Forth';
# SELECT * FROM mydata4;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# 5 rows affected.
# [(1, 'prolog', 'Colmerauer', 1972, 'ISO'),
#  (2, 'Perl', 'Wall', 1987, None),
#  (3, 'APL', 'Iverson', 1964, 'ANSI'),
#  (4, 'Tcl', 'Ousterhout', 1988, None),
#  (4, 'Forth', 'Moore', 1972, 'ANSI')]

# %%
# %%sql
#
# DELETE FROM mydata4 WHERE language = 'Forth';
# SELECT * FROM mydata4;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# 4 rows affected.
# [(1, 'prolog', 'Colmerauer', 1972, 'ISO'),
#  (2, 'Perl', 'Wall', 1987, None),
#  (3, 'APL', 'Iverson', 1964, 'ANSI'),
#  (4, 'Tcl', 'Ousterhout', 1988, None)]

# %% [markdown]
# One should be wary of statements of the form
#
# `DELETE FROM tablename;`
#
# Without a qualification, `DELETE` will remove all rows from the given table, leaving it empty. The
# system will not request confirmation before doing this!

# %% [markdown]
# #### Counting Records

# %%
# %sql SELECT COUNT(*) FROM mydata4;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(4,)]

# %%
# %sql SELECT COUNT(standard) FROM mydata4;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(2,)]

# %% [markdown]
# #### Column Aliases

# %%
# %sql SELECT id, language, author creator FROM mydata4;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 4 rows affected.
# [(1, 'prolog', 'Colmerauer'),
#  (2, 'Perl', 'Wall'),
#  (3, 'APL', 'Iverson'),
#  (4, 'Tcl', 'Ousterhout')]

# %% [markdown]
# #### `LIKE` operator
#
# For matching we are provided with two wildcard characters to use with `LIKE`.
#  - 1 % (Percent)	Used to match multiple characters including a single character and no character
#  - 2 _ (Underscore)	Used to match exactly one character

# %%
# %sql SELECT author, language FROM mydata4 WHERE language LIKE 'p%';
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [('Colmerauer', 'prolog')]

# %%
# %sql SELECT author, language FROM mydata4 WHERE language LIKE 'P%';
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [('Wall', 'Perl')]

# %%
# %sql SELECT author, language FROM mydata4 WHERE language LIKE '_P_';
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [('Iverson', 'APL')]

# %%
# %sql SELECT author, language FROM mydata4 WHERE language LIKE '__L';
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [('Iverson', 'APL')]

# %% [markdown]
# #### Mathematical Calculations

# %%
# %sql SELECT language, year - (year%10) decade FROM mydata4;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 4 rows affected.
# [('prolog', 1970), ('Perl', 1980), ('APL', 1960), ('Tcl', 1980)]

# %% [markdown]
# #### String Operation

# %%
# %sql SELECT language, 'The '||(year/10)*10||'s' decade FROM mydata4;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 4 rows affected.
# [('prolog', 'The 1970s'),
#  ('Perl', 'The 1980s'),
#  ('APL', 'The 1960s'),
#  ('Tcl', 'The 1980s')]

# %% [markdown]
# #### Aggregation and Grouping

# %%
# %%sql
# INSERT INTO mydata4 (id, language, author, year, standard) VALUES(5, 'Fortran', 'Backus', 1957, 'ANSI');
# INSERT INTO mydata4 (id, language, author, year, standard) VALUES(6, 'PL/I', 'IBM', 1964, 'ECMA');
# SELECT * FROM mydata4;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# 1 rows affected.
# 8 rows affected.
# [(1, 'prolog', 'Colmerauer', 1972, 'ISO'),
#  (2, 'Perl', 'Wall', 1987, None),
#  (3, 'APL', 'Iverson', 1964, 'ANSI'),
#  (4, 'Tcl', 'Ousterhout', 1988, None),
#  (5, 'Fortran', 'Backus', 1957, 'ANSI'),
#  (6, 'PL/I', 'IBM', 1964, 'ECMA'),
#  (5, 'Fortran', 'Backus', 1957, 'ANSI'),
#  (6, 'PL/I', 'IBM', 1964, 'ECMA')]

# %%
# %sql SELECT COUNT (DISTINCT YEAR) FROM mydata4;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(5,)]

# %%
# %sql SELECT COUNT (DISTINCT standard) FROM mydata4;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(3,)]

# %%
# %sql SELECT MIN(YEAR) FROM mydata4;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(1957,)]

# %%
# %sql SELECT language, MAX(year) FROM mydata4;  --wrong query
# Out:
#  * postgres://postgres:***@localhost/postgres
# (psycopg2.ProgrammingError) column "mydata4.language" must appear in the GROUP BY clause or be used in an aggregate function
# LINE 1: SELECT language, MAX(year) FROM mydata4;
#                ^
#  [SQL: 'SELECT language, MAX(year) FROM mydata4;'] (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %sql SELECT language, year FROM mydata4 WHERE year = (SELECT MAX(year) FROM mydata4);
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [('Tcl', 1988)]

# %% [markdown]
# ### `GROUP BY` Clause

# %%
# %%sql
#
# SELECT language, standard FROM mydata4 WHERE standard IS NOT NULL GROUP BY standard, language;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 4 rows affected.
# [('Fortran', 'ANSI'), ('prolog', 'ISO'), ('APL', 'ANSI'), ('PL/I', 'ECMA')]

# %% [markdown]
# Above example is unclear. How `GROUP BY` is working above?
#
# Note –You cannot group by a column which is not present in the SELECT list. You must specify all the columns in the grouping clause which are present in the SELECT list.
#
# The `GROUP BY` clause must appear right after `FROM` or (optionally) `WHERE` clause. Followed by the `GROUP BY` clause is one column or a list of comma separated columns. This clause may be followed by `ORDER BY` clause.  Also, the column(s) mentioned in `GROUP BY` clause must be present in `SELECT` clause.  The general syntax is like below –
#
# ```
# SELECT column_1, aggregate_function(column_2)
# FROM table_name
# WHERE some_condition (this is optional)
# GROUP BY column_1
# ORDER BY column_1 or aggregate_function(column2);
# ```
#
# ORDER OF EXECUTION – `FROM-> WHERE -> GROUPBY-> SELECT`

# %%
# %%sql
#
# CREATE TABLE employee (
# id INTEGER, name VARCHAR(20), salary INTEGER, age INTEGER);
# Out:
#  * postgres://postgres:***@localhost/postgres
# Done.
# (psycopg2.ProgrammingError) syntax error at or near "1"
# LINE 1: INSERT INTO employee (1, 'Harsh',2000, 19),(2, 'Dhanraj', 30...
#                               ^
#  [SQL: "INSERT INTO employee (1, 'Harsh',2000, 19),(2, 'Dhanraj', 3000, 20), (3, 'Ashish', 1500, 19), (4,'Harsh', 3500, 19),\n(5, 'Ashish', 1500,19);"] (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %%sql
# INSERT INTO employee VALUES (1, 'Harsh',2000, 19),(2, 'Dhanraj', 3000, 20), (3, 'Ashish', 1500, 19), (4,'Harsh', 3500, 19),
# (5, 'Ashish', 1500,19);
#
# SELECT * FROM employee;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 5 rows affected.
# 5 rows affected.
# [(1, 'Harsh', 2000, 19),
#  (2, 'Dhanraj', 3000, 20),
#  (3, 'Ashish', 1500, 19),
#  (4, 'Harsh', 3500, 19),
#  (5, 'Ashish', 1500, 19)]

# %%
# %sql SELECT name, SUM(salary) FROM employee GROUP BY name;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 3 rows affected.
# [('Ashish', 3000), ('Harsh', 5500), ('Dhanraj', 3000)]

# %%
# %sql SELECT name, SUM(salary) FROM employee WHERE name != 'Dhanraj' GROUP BY name HAVING SUM(salary) < 5000;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [('Ashish', 3000)]

# %% [markdown]
# #### Understanding Joining

# %%
# %%sql
#
# CREATE TABLE lang (id INTEGER NOT NULL PRIMARY KEY,language VARCHAR(20) NOT NULL,
#                    year INTEGER NOT NULL, standard VARCHAR(10) NULL);
#
# CREATE TABLE auth (author_id INTEGER NOT NULL, author VARCHAR(25) NOT NULL,
#                    language_id INTEGER);
# Out:
#  * postgres://postgres:***@localhost/postgres
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO lang VALUES (1,'Prolog', 1972, 'ISO'),(2,'Perl', 1987, NULL), (3,'APL', 1964,'ISO'), (4,'TCL', 1987,NULL), (5,'BASIC', 1964, 'ANSI');
# SELECT * FROM lang;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 5 rows affected.
# 5 rows affected.
# [(1, 'Prolog', 1972, 'ISO'),
#  (2, 'Perl', 1987, None),
#  (3, 'APL', 1964, 'ISO'),
#  (4, 'TCL', 1987, None),
#  (5, 'BASIC', 1964, 'ANSI')]

# %%
# %%sql
# INSERT INTO auth VALUES (5, 'Kemeny', 5), (6, 'Kurtz', 5),(1,'Colmerauer',1),(2,'Wall',2),(3,'Ousterhaut',4), (4, 'Iverson', 3);
# SELECT * FROM auth;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 6 rows affected.
# 6 rows affected.
# [(5, 'Kemeny', 5),
#  (6, 'Kurtz', 5),
#  (1, 'Colmerauer', 1),
#  (2, 'Wall', 2),
#  (3, 'Ousterhaut', 4),
#  (4, 'Iverson', 3)]

# %%
# %%sql
#
# SELECT author, language FROM auth, lang WHERE language_id = id;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 6 rows affected.
# [('Kemeny', 'BASIC'),
#  ('Kurtz', 'BASIC'),
#  ('Colmerauer', 'Prolog'),
#  ('Wall', 'Perl'),
#  ('Ousterhaut', 'TCL'),
#  ('Iverson', 'APL')]

# %%
# %%sql
#
# SELECT author, language FROM auth JOIN lang ON language_id = id;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 6 rows affected.
# [('Kemeny', 'BASIC'),
#  ('Kurtz', 'BASIC'),
#  ('Colmerauer', 'Prolog'),
#  ('Wall', 'Perl'),
#  ('Ousterhaut', 'TCL'),
#  ('Iverson', 'APL')]

# %% [markdown]
# #### Resolving ambiguity in join columns
#
# In our example the join condition fields had distinct names - `id` and `language_id`. But what if in our languages table (`lang`) we kept the key field’s name as `language_id`. This would create an ambiguity in the join condition, which would become the confusing `language_id = language_id`. To resolve this, we need to qualify the column by prepending it by the table name it belongs to and a `.`(period).

# %%
# %%sql
#
# SELECT author, language FROM auth JOIN lang ON auth.language_id = lang.id;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 6 rows affected.
# [('Kemeny', 'BASIC'),
#  ('Kurtz', 'BASIC'),
#  ('Colmerauer', 'Prolog'),
#  ('Wall', 'Perl'),
#  ('Ousterhaut', 'TCL'),
#  ('Iverson', 'APL')]

# %% [markdown]
# #### Self Join
#
# Relationship between 2 columns from same table.

# %%
# %%sql
#
# CREATE TABLE inflang (id INTEGER PRIMARY KEY,language VARCHAR(20) NOT NULL, influenced_by INTEGER);
#
# INSERT INTO inflang VALUES (1, 'Fortran', NULL), (2, 'Pascal',3),(3, 'Algol',1);
#
# SELECT * FROM inflang;
# Out:
#  * postgres://postgres:***@localhost/postgres
# Done.
# 3 rows affected.
# 3 rows affected.
# [(1, 'Fortran', None), (2, 'Pascal', 3), (3, 'Algol', 1)]

# %%
# %%sql
#
# SELECT l1.language, l2.language AS influenced FROM inflang l1, inflang l2 WHERE l1.id = l2.influenced_by;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 2 rows affected.
# [('Algol', 'Pascal'), ('Fortran', 'Algol')]

# %% [markdown]
# Notice the use of table aliases to qualify the join condition columns as separate and the use of the `AS` keyword which renames the column in the output.

# %% [markdown]
# ##### Subqueries
#
# A subquery, simply put, is a query written as a part of a bigger statement. Think of it as a `SELECT` statement inside another one. The result of the inner `SELECT` can then be used in the outer query.

# %%
# %%sql
#
# SELECT author FROM auth WHERE language_id IN (SELECT id FROM lang WHERE language = 'TCL');
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [('Ousterhaut',)]

# %% [markdown]
# There are basically 2 types of subqueries. First one scalar subquery which returns only a single column of a single row.  The query we ran just above is an example of scalar subquery. Other type of subquery is Table subquery which returns a table in itself. Example is below –

# %%
# %%sql
# SELECT author, language FROM auth a,(SELECT id, language FROM lang WHERE year > 1980) n WHERE a.language_id = n.id;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 2 rows affected.
# [('Wall', 'Perl'), ('Ousterhaut', 'TCL')]

# %% [markdown]
# Using subqueries in `INSERT` statements – Let’s first insert a record in `lang` table –

# %%
# %%sql
#
# INSERT INTO lang (id, language, year, standard) VALUES(6, 'Pascal', 1970, 'ISO');
# SELECT * FROM lang;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# 6 rows affected.
# [(1, 'Prolog', 1972, 'ISO'),
#  (2, 'Perl', 1987, None),
#  (3, 'APL', 1964, 'ISO'),
#  (4, 'TCL', 1987, None),
#  (5, 'BASIC', 1964, 'ANSI'),
#  (6, 'Pascal', 1970, 'ISO')]

# %%
# %%sql
#
# INSERT INTO auth (author_id, author, language_id) VALUES(7, 'Wirth', (SELECT id FROM lang WHERE language = 'Pascal'));
# SELECT * FROM auth;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# 7 rows affected.
# [(5, 'Kemeny', 5),
#  (6, 'Kurtz', 5),
#  (1, 'Colmerauer', 1),
#  (2, 'Wall', 2),
#  (3, 'Ousterhaut', 4),
#  (4, 'Iverson', 3),
#  (7, 'Wirth', 6)]

# %%
# %%sql
#
# SELECT language, standard FROM lang WHERE standard  = 'ISO' OR standard IS Null;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 5 rows affected.
# [('Prolog', 'ISO'),
#  ('Perl', None),
#  ('APL', 'ISO'),
#  ('TCL', None),
#  ('Pascal', 'ISO')]

# %% [markdown]
# #### `WHERE EXISTS`

# %%
# %%sql
# SELECT year FROM lang WHERE EXISTS(SELECT author FROM auth WHERE language_id = lang.id AND language_id > 4);
# Out:
#  * postgres://postgres:***@localhost/postgres
# 2 rows affected.
# [(1964,), (1970,)]

# %% [markdown]
# #### VIEWS

# %%
# %%sql
#
# CREATE VIEW test AS SELECT language, author  FROM mydata4;
# Out:
#  * postgres://postgres:***@localhost/postgres
# Done.
# []

# %%
# %sql SELECT * FROM test;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 8 rows affected.
# [('prolog', 'Colmerauer'),
#  ('Perl', 'Wall'),
#  ('APL', 'Iverson'),
#  ('Tcl', 'Ousterhout'),
#  ('Fortran', 'Backus'),
#  ('PL/I', 'IBM'),
#  ('Fortran', 'Backus'),
#  ('PL/I', 'IBM')]

# %% [markdown]
# To delete view, use `DROP VIEW`.
#
# Also, view `test` depends on table `mydata`. If you try to remove `mydata`, a warning will be raised.

# %%
# %sql DROP TABLE mydata4; -- error raised because view 'test' depends on this table
# Out:
#  * postgres://postgres:***@localhost/postgres
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#
# InternalError: cannot drop table mydata4 because other objects depend on it
# DETAIL:  view test depends on table mydata4
# HINT:  Use DROP ... CASCADE to drop the dependent objects too.
#
#
# The above exception was the direct cause of the following exception:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-162-1c9430d7c3ee> in <module>()
# ----> 1 get_ipython().magic('sql DROP TABLE mydata4;')
#
# C:\miniconda3\envs\data\lib\site-packages\IPython\core\interactiveshell.py in magic(self, arg_s)
#    2144         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2145         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2146         return self.run_line_magic(magic_name, magic_arg_s)
#    2147
#    2148     #-------------------------------------------------------------------------
#
# C:\miniconda3\envs\data\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line)
#    2065                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2066             with self.builtin_trap:
# -> 2067                 result = fn(*args,**kwargs)
#    2068             return result
#    2069
#
# <decorator-gen-127> in execute(self, line, cell, local_ns)
#
# C:\miniconda3\envs\data\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# <decorator-gen-126> in execute(self, line, cell, local_ns)
#
# C:\miniconda3\envs\data\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\miniconda3\envs\data\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# C:\miniconda3\envs\data\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     338             else:
#     339                 txt = sqlalchemy.sql.text(statement)
# --> 340                 result = conn.session.execute(txt, user_namespace)
#     341             _commit(conn=conn, config=config)
#     342             if result and config.feedback:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object, *multiparams, **params)
#     946             raise exc.ObjectNotExecutableError(object)
#     947         else:
# --> 948             return meth(self, multiparams, params)
#     949
#     950     def _execute_function(self, func, multiparams, params):
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     267     def _execute_on_connection(self, connection, multiparams, params):
#     268         if self.supports_execution:
# --> 269             return connection._execute_clauseelement(self, multiparams, params)
#     270         else:
#     271             raise exc.ObjectNotExecutableError(self)
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1058             compiled_sql,
#    1059             distilled_params,
# -> 1060             compiled_sql, distilled_params
#    1061         )
#    1062         if self._has_events or self.engine._has_events:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1191                         statement,
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#    1195             self._handle_dbapi_exception(
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     505
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#     509     def do_execute_no_params(self, cursor, statement, context=None):
#
# InternalError: (psycopg2.InternalError) cannot drop table mydata4 because other objects depend on it
# DETAIL:  view test depends on table mydata4
# HINT:  Use DROP ... CASCADE to drop the dependent objects too.
#  [SQL: 'DROP TABLE mydata4;'] (Background on this error at: http://sqlalche.me/e/2j85)

# %% [markdown]
# To drop the table and dependent objects, we issue following command -
#
# `DROP TABLE mydata4 CASCADE;`

# %% [markdown]
# #### Some bits

# %%
# %sql SELECT current_date;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(datetime.date(2018, 9, 30),)]

# %%
# %sql SELECT (5+4)/2;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(4,)]

# %%
# %sql SELECT (5+4)/2.;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(Decimal('4.5000000000000000'),)]

# %%
# %sql SELECT CHAR_LENGTH('ABCDE');  -- CHARACTER_LENGTH can also be used
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(5,)]

# %% [markdown]
# #### PostgreSQL Official Tutorial

# %%
# %%sql
#
# CREATE TABLE weather(
# city VARCHAR(80),
# temp_lo int,
# temp_hi int,  --high temperature
# prcp real,    --precipitation
# date date);
#
# CREATE TABLE cities(
# name VARCHAR(80),
# location point); -- point is postgresql specific data type
# Out:
#  * postgres://postgres:***@localhost/postgres
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO weather VALUES ('San Francisco', 46, 50, 0.25, '1994-11-27'), ('San Francisco', 43, 57, 0, '1994-11-29'),
# ('Hayward', 37, 54, NULL, '1994-11-29');
#
# SELECT * FROM weather;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 3 rows affected.
# 3 rows affected.
# [('San Francisco', 46, 50, 0.25, datetime.date(1994, 11, 27)),
#  ('San Francisco', 43, 57, 0.0, datetime.date(1994, 11, 29)),
#  ('Hayward', 37, 54, None, datetime.date(1994, 11, 29))]

# %%
# %%sql
#
# INSERT INTO cities VALUES ('San Francisco', '(-194,53)');
# SELECT * FROM cities;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# 1 rows affected.
# [('San Francisco', '(-194,53)')]

# %%
# %%sql
#
# SELECT city, temp_lo, temp_hi, prcp, date, location FROM weather, cities WHERE city = name;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 2 rows affected.
# [('San Francisco', 46, 50, 0.25, datetime.date(1994, 11, 27), '(-194,53)'),
#  ('San Francisco', 43, 57, 0.0, datetime.date(1994, 11, 29), '(-194,53)')]

# %%
# %%sql
# SELECT * FROM weather INNER JOIN cities ON (weather.city = cities.name); --alternate form, same as above
# Out:
#  * postgres://postgres:***@localhost/postgres
# 2 rows affected.
# [('San Francisco', 46, 50, 0.25, datetime.date(1994, 11, 27), 'San Francisco', '(-194,53)'),
#  ('San Francisco', 43, 57, 0.0, datetime.date(1994, 11, 29), 'San Francisco', '(-194,53)')]

# %%
# %%sql
# SELECT *
# FROM weather LEFT OUTER JOIN cities ON (weather.city = cities.name); --columns from left table appear at least once
# Out:
#  * postgres://postgres:***@localhost/postgres
# 3 rows affected.
# [('San Francisco', 46, 50, 0.25, datetime.date(1994, 11, 27), 'San Francisco', '(-194,53)'),
#  ('San Francisco', 43, 57, 0.0, datetime.date(1994, 11, 29), 'San Francisco', '(-194,53)'),
#  ('Hayward', 37, 54, None, datetime.date(1994, 11, 29), None, None)]

# %%
# %%sql
# SELECT *
# FROM weather RIGHT OUTER JOIN cities ON (weather.city = cities.name);
# Out:
#  * postgres://postgres:***@localhost/postgres
# 2 rows affected.
# [('San Francisco', 43, 57, 0.0, datetime.date(1994, 11, 29), 'San Francisco', '(-194,53)'),
#  ('San Francisco', 46, 50, 0.25, datetime.date(1994, 11, 27), 'San Francisco', '(-194,53)')]

# %%
# %%sql
# SELECT *
# FROM weather FULL OUTER JOIN cities ON (weather.city = cities.name); --columns from left table appear at least once
# Out:
#  * postgres://postgres:***@localhost/postgres
# 3 rows affected.
# [('San Francisco', 46, 50, 0.25, datetime.date(1994, 11, 27), 'San Francisco', '(-194,53)'),
#  ('San Francisco', 43, 57, 0.0, datetime.date(1994, 11, 29), 'San Francisco', '(-194,53)'),
#  ('Hayward', 37, 54, None, datetime.date(1994, 11, 29), None, None)]

# %%
# %%sql
#
# -- self join
#
# SELECT W1.city, W1.temp_lo AS low, W1.temp_hi AS high,
# W2.city, W2.temp_lo AS low, W2.temp_hi AS high
# FROM weather W1, weather W2
# WHERE W1.temp_lo < W2.temp_lo
# AND W1.temp_hi > W2.temp_hi;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 2 rows affected.
# [('San Francisco', 43, 57, 'San Francisco', 46, 50),
#  ('Hayward', 37, 54, 'San Francisco', 46, 50)]

# %% [markdown]
# In tutorial, the output columns name are different from what we are seeing here. In fact, when this query is run in command prompt, the column names are different from what we are seeing here but same as seen in tutorial. Why?

# %% [markdown]
# ##### Aggregate Functions

# %%
# %sql SELECT max(temp_lo) FROM weather;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(46,)]

# %%
# %sql SELECT city FROM weather WHERE temp_lo = max(temp_lo); -- wrong
# Out:
#  * postgres://postgres:***@localhost/postgres
# (psycopg2.ProgrammingError) aggregate functions are not allowed in WHERE
# LINE 1: SELECT city FROM weather WHERE temp_lo = max(temp_lo); -- wr...
#                                                  ^
#  [SQL: 'SELECT city FROM weather WHERE temp_lo = max(temp_lo); -- wrong'] (Background on this error at: http://sqlalche.me/e/f405)

# %% [markdown]
# This query does not work since the aggregate `max` cannot be used in the `WHERE` clause. (This restriction
# exists because the `WHERE` clause determines which rows will be included in the aggregate calculation;
# so obviously it has to be evaluated before aggregate functions are computed.) However, as is often the
# case the query can be restated to accomplish the desired result, here by using a *subquery*:

# %%
# %sql SELECT city FROM weather WHERE temp_lo = (SELECT max(temp_lo) FROM weather);
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [('San Francisco',)]

# %%
# %sql SELECT city, max(temp_lo) FROM weather GROUP BY city;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 2 rows affected.
# [('San Francisco', 46), ('Hayward', 37)]

# %%
# %sql SELECT city, max(temp_lo) FROM weather GROUP BY city HAVING max(temp_lo) <40;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [('Hayward', 37)]

# %%
# %sql SELECT city, max(temp_lo) FROM weather WHERE city LIKE 'S%' GROUP BY city HAVING max(temp_lo) <40;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 0 rows affected.
# []

# %% [markdown]
# It is important to understand the interaction between aggregates and SQL's `WHERE` and `HAVING`
# clauses. The fundamental difference between `WHERE` and `HAVING` is this: `WHERE` selects input
# rows before groups and aggregates are computed (thus, it controls which rows go into the aggregate
# computation), whereas `HAVING` selects group rows after groups and aggregates are computed. Thus,
# the `WHERE` clause must not contain aggregate functions; it makes no sense to try to use an aggregate
# to determine which rows will be inputs to the aggregates. On the other hand, the `HAVING` clause
# always contains aggregate functions. (Strictly speaking, you are allowed to write a `HAVING` clause
# that doesn't use aggregates, but it's seldom useful. The same condition could be used more efficiently
# at the `WHERE` stage.)
# In the previous example, we can apply the city name restriction in `WHERE`, since it needs no aggregate.
# This is more efficient than adding the restriction to `HAVING`, because we avoid doing the grouping
# and aggregate calculations for all rows that fail the `WHERE` check.

# %% [markdown]
# ### Foreign Keys
#
# Consider the following problem: You want
# to make sure that no one can insert rows in the `weather` table that do not have a matching entry
# in the `cities` table. This is called maintaining the referential integrity of your data. In simplistic
# database systems this would be implemented (if at all) by first looking at the `cities` table to check
# if a matching record exists, and then inserting or rejecting the new `weather` records. This approach
# has a number of problems and is very inconvenient, so PostgreSQL can do this for you.

# %%
# %%sql
#
# CREATE TABLE cities1(
# city VARCHAR(80) PRIMARY KEY,
# location point);
#
#
# CREATE TABLE weather1(
# city VARCHAR(80) REFERENCES cities1(city),
# temp_lo int,
# temp_hi int,  --high temperature
# prcp real,    --precipitation
# date date);
# Out:
#  * postgres://postgres:***@localhost/postgres
# Done.
# Done.
# []

# %% [markdown]
# Now try inserting following record -

# %%
# %%sql
# INSERT INTO weather1 VALUES ('Berkeley', 45, 53, 0.0, '1994-11-28'); --error
# Out:
#  * postgres://postgres:***@localhost/postgres
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#
# IntegrityError: insert or update on table "weather1" violates foreign key constraint "weather1_city_fkey"
# DETAIL:  Key (city)=(Berkeley) is not present in table "cities1".
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-199-8e05770d63f5> in <module>()
# ----> 1 get_ipython().run_cell_magic('sql', '', "INSERT INTO weather1 VALUES ('Berkeley', 45, 53, 0.0, '1994-11-28');")
#
# C:\miniconda3\envs\data\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2101             magic_arg_s = self.var_expand(line, stack_depth)
#    2102             with self.builtin_trap:
# -> 2103                 result = fn(magic_arg_s, cell)
#    2104             return result
#    2105
#
# <decorator-gen-127> in execute(self, line, cell, local_ns)
#
# C:\miniconda3\envs\data\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# <decorator-gen-126> in execute(self, line, cell, local_ns)
#
# C:\miniconda3\envs\data\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\miniconda3\envs\data\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# C:\miniconda3\envs\data\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     338             else:
#     339                 txt = sqlalchemy.sql.text(statement)
# --> 340                 result = conn.session.execute(txt, user_namespace)
#     341             _commit(conn=conn, config=config)
#     342             if result and config.feedback:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object, *multiparams, **params)
#     946             raise exc.ObjectNotExecutableError(object)
#     947         else:
# --> 948             return meth(self, multiparams, params)
#     949
#     950     def _execute_function(self, func, multiparams, params):
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     267     def _execute_on_connection(self, connection, multiparams, params):
#     268         if self.supports_execution:
# --> 269             return connection._execute_clauseelement(self, multiparams, params)
#     270         else:
#     271             raise exc.ObjectNotExecutableError(self)
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1058             compiled_sql,
#    1059             distilled_params,
# -> 1060             compiled_sql, distilled_params
#    1061         )
#    1062         if self._has_events or self.engine._has_events:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1191                         statement,
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#    1195             self._handle_dbapi_exception(
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     505
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#     509     def do_execute_no_params(self, cursor, statement, context=None):
#
# IntegrityError: (psycopg2.IntegrityError) insert or update on table "weather1" violates foreign key constraint "weather1_city_fkey"
# DETAIL:  Key (city)=(Berkeley) is not present in table "cities1".
#  [SQL: "INSERT INTO weather1 VALUES ('Berkeley', 45, 53, 0.0, '1994-11-28');"] (Background on this error at: http://sqlalche.me/e/gkpj)

# %% [markdown]
# Above insertion fails because there was no matching record in `cities1` table.

# %% [markdown]
# [Source](www.postgresqltutorial.com/postgresql-foreign-key/) for following section -
#
# Let us create 2 tables as shown below -
#
# ```
# CREATE TABLE so_headers (
# id SERIAL PRIMARY KEY,
# customer_id INTEGER,
# ship_to VARCHAR (255)
# );
#
# CREATE TABLE so_items (
# item_id INTEGER NOT NULL,
# so_id INTEGER REFERENCES so_headers(id), --foreign key constraint
# product_id INTEGER,
# qty INTEGER,
# net_price numeric,
# PRIMARY KEY (item_id,so_id)
# );
# ```
# foreign key in `so_items` can also be defined as shown below -
# ```
# CREATE TABLE so_items (
#  item_id INTEGER NOT NULL,
#  so_id INTEGER,
#  product_id INTEGER,
#  qty INTEGER,
#  net_price NUMERIC,
#  PRIMARY KEY(item_id, so_id),
#  FOREIGN KEY(so_id) REFERENCES so_headers(id)
# );
# ```
#
# Because we didn’t specify a name for the foreign key constraint explicitly, PostgreSQL assigned a name with the pattern: `table_column_fkey`. In our example, PostgreSQL creates a foreign key constraint as `so_items_so_id_fkey`.
#
# Each line item of a sales order must belong to a specific sales order. Each sales order can have one or many line items. This is call one-to-many relationship. We cannot insert a row into the `so_items` without referencing to a valid `id` in the `so_headers` table. (This last line is different in original source and seemingly wrong.)
#
# What will happen to the rows in the `so_items` table when a row in the `so_headers` is deleted? PostgreSQL gives us the following main options: `DELETE RESTRICT`, `DELETE CASCADE` and `NO ACTION`.
#
# PostgreSQL does not delete a row in the so_headers table until all referenced rows in the so_items deleted. To achieve this, we use `ON DELETE RESTRICT` expression when we define the foreign key constraint.
#
#     so_id int4 REFERENCES so_headers(id) ON DELETE RESTRICT
#
# PostgreSQL will delete all rows in the `so_items` table that are referenced to the rows that are being deleted in the `so_headers` table. To instruct PostgreSQL to do this, we use `ON DELETE CASCADE`.
#
# In case a foreign key is a group of columns, we define the foreign key constraint using the following syntax:
# ```
# CREATE TABLE child_table(
#   c1 INTEGER PRIMARY KEY,
#   c2 INTEGER,
#   c3 INTEGER,
#   FOREIGN KEY (c2, c3) REFERENCES parent_table (p1, p2)
# );
# ```

# %% [markdown]
# ### Transactions
#
# The essential point of a transaction is that it bundles multiple steps into a single, all-or-nothing operation.
#
# In PostgreSQL, a transaction is set up by surrounding the SQL commands of the transaction with
# `BEGIN` and `COMMIT` commands. So our banking transaction would actually look like:
# ```
# BEGIN;
# UPDATE accounts SET balance = balance - 100.00
# WHERE name = 'Alice';
# -- etc etc
# COMMIT;
# ```

# %% [markdown]
# ### Window Functions

# %%
# %%sql
#
# CREATE TABLE empsalary (depname VARCHAR(20),
#                        empno INTEGER,
#                        salary INTEGER);
# Out:
#  * postgres://postgres:***@localhost/postgres
# Done.
# []

# %%
# %%sql
#
# INSERT INTO empsalary VALUES ('develop',11,5200),('develop',7,4200),('develop',9,4500),('develop',8,6000),
# ('personnel',5,3500),('personnel',2,3900),('sales',3,4800),('sales',1,5000),('sales',4,4800);
#
# SELECT * FROM empsalary;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 9 rows affected.
# 9 rows affected.
# [('develop', 11, 5200),
#  ('develop', 7, 4200),
#  ('develop', 9, 4500),
#  ('develop', 8, 6000),
#  ('personnel', 5, 3500),
#  ('personnel', 2, 3900),
#  ('sales', 3, 4800),
#  ('sales', 1, 5000),
#  ('sales', 4, 4800)]

# %%
# %sql SELECT depname, empno, salary, avg(salary) OVER (PARTITION BY depname) FROM empsalary;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 9 rows affected.
# [('develop', 11, 5200, Decimal('4975.0000000000000000')),
#  ('develop', 7, 4200, Decimal('4975.0000000000000000')),
#  ('develop', 9, 4500, Decimal('4975.0000000000000000')),
#  ('develop', 8, 6000, Decimal('4975.0000000000000000')),
#  ('personnel', 5, 3500, Decimal('3700.0000000000000000')),
#  ('personnel', 2, 3900, Decimal('3700.0000000000000000')),
#  ('sales', 3, 4800, Decimal('4866.6666666666666667')),
#  ('sales', 1, 5000, Decimal('4866.6666666666666667')),
#  ('sales', 4, 4800, Decimal('4866.6666666666666667'))]

# %% [markdown]
# A window function call always contains an `OVER` clause directly following the window function's
# name and argument(s). This is what syntactically distinguishes it from a normal function or nonwindow
# aggregate. The `OVER` clause determines exactly how the rows of the query are split up for
# processing by the window function. The `PARTITION BY` clause within `OVER` divides the rows into
# groups, or partitions, that share the same values of the `PARTITION BY` expression(s). For each row,
# the window function is computed across the rows that fall into the same partition as the current row.

# %%
# %sql SELECT depname, empno, salary, rank() OVER (PARTITION BY depname ORDER BY salary DESC) FROM empsalary;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 9 rows affected.
# [('develop', 8, 6000, 1),
#  ('develop', 11, 5200, 2),
#  ('develop', 9, 4500, 3),
#  ('develop', 7, 4200, 4),
#  ('personnel', 2, 3900, 1),
#  ('personnel', 5, 3500, 2),
#  ('sales', 1, 5000, 1),
#  ('sales', 3, 4800, 2),
#  ('sales', 4, 4800, 2)]

# %% [markdown]
# **Note**- Notice the use of `rank()` above.

# %% [markdown]
# As shown here, the `rank` function produces a numerical rank for each distinct `ORDER BY` value in
# the current row's partition, using the order defined by the `ORDER BY` clause. `rank` needs no explicit
# parameter, because its behavior is entirely determined by the `OVER` clause.

# %%
# %sql SELECT salary, sum(salary) OVER () FROM empsalary;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 9 rows affected.
# [(5200, 41900),
#  (4200, 41900),
#  (4500, 41900),
#  (6000, 41900),
#  (3500, 41900),
#  (3900, 41900),
#  (4800, 41900),
#  (5000, 41900),
#  (4800, 41900)]

# %% [markdown]
# Above, since there is no `ORDER BY` in the `OVER` clause, the window frame is the same as the partition,
# which for lack of `PARTITION BY` is the whole table; in other words each sum is taken over the
# whole table and so we get the same result for each output row. But if we add an `ORDER BY` clause,
# we get very different results:

# %%
# %sql SELECT salary, sum(salary) OVER (ORDER BY salary) FROM empsalary;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 9 rows affected.
# [(3500, 3500),
#  (3900, 7400),
#  (4200, 11600),
#  (4500, 16100),
#  (4800, 25700),
#  (4800, 25700),
#  (5000, 30700),
#  (5200, 35900),
#  (6000, 41900)]

# %% [markdown]
# Here the sum is taken from the first (lowest) salary up through the current one, including any duplicates
# of the current one (notice the results for the duplicated salaries).
# Window functions are permitted only in the `SELECT` list and the `ORDER BY` clause of the query.
# They are forbidden elsewhere, such as in `GROUP BY`, `HAVING` and `WHERE` clauses. This is because
# they logically execute after the processing of those clauses. Also, window functions execute after
# non-window aggregate functions. This means it is valid to include an aggregate function call in the
# arguments of a window function, but not vice versa.

# %% [markdown]
# ### Inheritance

# %%
# %%sql
#
# CREATE TABLE city (
# name text,
# population real,
# altitude int -- (in ft)
# );
#
# CREATE TABLE capitals (
# state char(2)
# ) INHERITS (city); -- Notice INHERITS
# Out:
#  * postgres://postgres:***@localhost/postgres
# Done.
# Done.
# []

# %%
# %%sql
#
# INSERT INTO city VALUES ('Lucknow', 1000000, 100);
# INSERT INTO capitals VALUES ('Lucknow', 1000000, 100,'UP');
#
# SELECT * FROM city;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# 1 rows affected.
# 2 rows affected.
# [('Lucknow', 1000000.0, 100), ('Lucknow', 1000000.0, 100)]

# %%
# %sql SELECT * FROM capitals;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [('Lucknow', 1000000.0, 100, 'UP')]

# %% [markdown]
# ### Modifying Table

# %%
# %sql SELECT * FROM mydata;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 2 rows affected.
# [('prolog', 'ISO'), ('APL', 'ANSI')]

# %% [markdown]
# ##### Adding Column

# %%
# %sql ALTER TABLE mydata ADD COLUMN year INTEGER;
# Out:
#  * postgres://postgres:***@localhost/postgres
# Done.
# []

# %%
# %sql SELECT * FROM mydata;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 2 rows affected.
# [('prolog', 'ISO', None), ('APL', 'ANSI', None)]

# %% [markdown]
# ##### Renaming Table

# %%
# %sql ALTER TABLE mydata RENAME TO language;
# Out:
#  * postgres://postgres:***@localhost/postgres
# Done.
# []

# %%
# %sql SELECT * FROM language;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 2 rows affected.
# [('prolog', 'ISO', None), ('APL', 'ANSI', None)]

# %% [markdown]
# ##### Renaming Column

# %%
# %%sql
#
# ALTER TABLE language RENAME COLUMN year TO decade;
# SELECT * FROM language;
# Out:
#  * postgres://postgres:***@localhost/postgres
# Done.
# 2 rows affected.
# [('prolog', 'ISO', None), ('APL', 'ANSI', None)]

# %% [markdown]
# ##### Adding Default

# %%
# %%sql
#
# ALTER TABLE language ALTER COLUMN decade SET DEFAULT 1900;
# SELECT * FROM language;
# Out:
#  * postgres://postgres:***@localhost/postgres
# Done.
# 2 rows affected.
# [('prolog', 'ISO', None), ('APL', 'ANSI', None)]

# %% [markdown]
# Only future records are affected. Past records remain unaffected.

# %%
# %%sql
#
# INSERT INTO language VALUES ('C', 'ANSI');
# SELECT * FROM language;
# Out:
#  * postgres://postgres:***@localhost/postgres
# 1 rows affected.
# 3 rows affected.
# [('prolog', 'ISO', None), ('APL', 'ANSI', None), ('C', 'ANSI', 1900)]

# %% [markdown]
# ##### Adding Constraint

# %%
# %%sql
#
# ALTER TABLE language ALTER COLUMN standard SET NOT NULL;
# INSERT INTO language VALUES('Fortran', Null);               --error
# SELECT * FROM language;
# Out:
#  * postgres://postgres:***@localhost/postgres
# Done.
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#
# IntegrityError: null value in column "standard" violates not-null constraint
# DETAIL:  Failing row contains (Fortran, null, 1900).
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-226-7e936cec294c> in <module>()
# ----> 1 get_ipython().run_cell_magic('sql', '', "\nALTER TABLE language ALTER COLUMN standard SET NOT NULL;\nINSERT INTO language VALUES('Fortran', Null);\nSELECT * FROM language;")
#
# C:\miniconda3\envs\data\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2101             magic_arg_s = self.var_expand(line, stack_depth)
#    2102             with self.builtin_trap:
# -> 2103                 result = fn(magic_arg_s, cell)
#    2104             return result
#    2105
#
# <decorator-gen-127> in execute(self, line, cell, local_ns)
#
# C:\miniconda3\envs\data\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# <decorator-gen-126> in execute(self, line, cell, local_ns)
#
# C:\miniconda3\envs\data\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\miniconda3\envs\data\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# C:\miniconda3\envs\data\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     338             else:
#     339                 txt = sqlalchemy.sql.text(statement)
# --> 340                 result = conn.session.execute(txt, user_namespace)
#     341             _commit(conn=conn, config=config)
#     342             if result and config.feedback:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object, *multiparams, **params)
#     946             raise exc.ObjectNotExecutableError(object)
#     947         else:
# --> 948             return meth(self, multiparams, params)
#     949
#     950     def _execute_function(self, func, multiparams, params):
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     267     def _execute_on_connection(self, connection, multiparams, params):
#     268         if self.supports_execution:
# --> 269             return connection._execute_clauseelement(self, multiparams, params)
#     270         else:
#     271             raise exc.ObjectNotExecutableError(self)
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1058             compiled_sql,
#    1059             distilled_params,
# -> 1060             compiled_sql, distilled_params
#    1061         )
#    1062         if self._has_events or self.engine._has_events:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1191                         statement,
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#    1195             self._handle_dbapi_exception(
#
# C:\miniconda3\envs\data\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     505
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#     509     def do_execute_no_params(self, cursor, statement, context=None):
#
# IntegrityError: (psycopg2.IntegrityError) null value in column "standard" violates not-null constraint
# DETAIL:  Failing row contains (Fortran, null, 1900).
#  [SQL: "INSERT INTO language VALUES('Fortran', Null);"] (Background on this error at: http://sqlalche.me/e/gkpj)

# %% [markdown]
# The `INSERT` command won't work because standard value can't be `Null`.
#
# **Other Commands**
#
#  - Droping columns
#
# `ALTER TABLE products DROP COLUMN description;`
#
# Whatever data was in the column disappears. Table constraints involving the column are dropped, too. However, if the column is referenced by a foreign key constraint of another table, PostgreSQL will not silently drop that constraint. You can authorize dropping everything that depends on the column by adding `CASCADE`:
#
# `ALTER TABLE products DROP COLUMN description CASCADE;`
#
#  - To remove any default value, use:
#
# `ALTER TABLE products ALTER COLUMN price DROP DEFAULT;`
#
# This is effectively the same as setting the default to null. As a consequence, it is not an error to drop a default where one hadn't been defined, because the default is implicitly the null value.
#
#  - Removing a constraint
#
# `ALTER TABLE products DROP CONSTRAINT some_name;`
#
#  - To convert a column to a different data type, use a command like:
#
# `ALTER TABLE products ALTER COLUMN price TYPE numeric(10,2);`
#
# This will succeed only if each existing entry in the column can be converted to the new type by an
# implicit cast.

# %% [markdown]
# #### SUBQUERY EXPRESSION –
#
# ```
# EXISTS (subquery)
# expression IN (subquery)
# expression NOT IN (subquery)
# expression operator ANY (subquery)
# expression operator SOME (subquery)
# expression operator All (subquery)
# ```

# %% [markdown]
# ---
# ### Exercises
#
# from [pgexercises](www.pgexercises.com)
#
# There are 3 tables -
#
#  - `cd.members`
#  - `cd.facilities`
#  - `cd.bookings`

# %% [markdown]
# ![](images/pgschema.png)

# %%
# %load_ext sql

# %%
# %%sql
#
# postgres://postgres:xyzaaa@localhost/exercises
# Out:
# 'Connected: postgres@exercises'

# %%
# %%sql
# --first exercise
# SELECT * FROM cd.facilities;
# Out:
#  * postgres://postgres:***@localhost/exercises
# 9 rows affected.
# [(0, 'Tennis Court 1', Decimal('5'), Decimal('25'), Decimal('10000'), Decimal('200')),
#  (1, 'Tennis Court 2', Decimal('5'), Decimal('25'), Decimal('8000'), Decimal('200')),
#  (2, 'Badminton Court', Decimal('0'), Decimal('15.5'), Decimal('4000'), Decimal('50')),
#  (3, 'Table Tennis', Decimal('0'), Decimal('5'), Decimal('320'), Decimal('10')),
#  (4, 'Massage Room 1', Decimal('35'), Decimal('80'), Decimal('4000'), Decimal('3000')),
#  (5, 'Massage Room 2', Decimal('35'), Decimal('80'), Decimal('4000'), Decimal('3000')),
#  (6, 'Squash Court', Decimal('3.5'), Decimal('17.5'), Decimal('5000'), Decimal('80')),
#  (7, 'Snooker Table', Decimal('0'), Decimal('5'), Decimal('450'), Decimal('15')),
#  (8, 'Pool Table', Decimal('0'), Decimal('5'), Decimal('400'), Decimal('15'))]

# %%
# %%sql
# -- second exercise
# SELECT name, membercost FROM cd.facilities;
# Out:
#  * postgres://postgres:***@localhost/exercises
# 9 rows affected.
# [('Tennis Court 1', Decimal('5')),
#  ('Tennis Court 2', Decimal('5')),
#  ('Badminton Court', Decimal('0')),
#  ('Table Tennis', Decimal('0')),
#  ('Massage Room 1', Decimal('35')),
#  ('Massage Room 2', Decimal('35')),
#  ('Squash Court', Decimal('3.5')),
#  ('Snooker Table', Decimal('0')),
#  ('Pool Table', Decimal('0'))]

# %%
# %%sql
# -- 3rd exercise - find out rows where membercost is not zero
# SELECT * FROM cd.facilities WHERE membercost > 0;
# Out:
#  * postgres://postgres:***@localhost/exercises
# 5 rows affected.
# [(0, 'Tennis Court 1', Decimal('5'), Decimal('25'), Decimal('10000'), Decimal('200')),
#  (1, 'Tennis Court 2', Decimal('5'), Decimal('25'), Decimal('8000'), Decimal('200')),
#  (4, 'Massage Room 1', Decimal('35'), Decimal('80'), Decimal('4000'), Decimal('3000')),
#  (5, 'Massage Room 2', Decimal('35'), Decimal('80'), Decimal('4000'), Decimal('3000')),
#  (6, 'Squash Court', Decimal('3.5'), Decimal('17.5'), Decimal('5000'), Decimal('80'))]

# %%
# %%sql
# -- 4th exercise
# SELECT facid, name, membercost, monthlymaintenance FROM cd.facilities WHERE membercost > 0 and membercost < .02*monthlymaintenance;
# Out:
#  * postgres://postgres:***@localhost/exercises
# 2 rows affected.
# [(4, 'Massage Room 1', Decimal('35'), Decimal('3000')),
#  (5, 'Massage Room 2', Decimal('35'), Decimal('3000'))]

# %%
# %%sql
# -- 5th exercise
# SELECT * FROM cd.facilities WHERE name LIKE '%Tennis%' ;
# Out:
#  * postgres://postgres:***@localhost/exercises
# 3 rows affected.
# [(0, 'Tennis Court 1', Decimal('5'), Decimal('25'), Decimal('10000'), Decimal('200')),
#  (1, 'Tennis Court 2', Decimal('5'), Decimal('25'), Decimal('8000'), Decimal('200')),
#  (3, 'Table Tennis', Decimal('0'), Decimal('5'), Decimal('320'), Decimal('10'))]

# %%
# %%sql
# -- this was asked in CTS interview, I failed to answer this
# SELECT membercost, count(*) FROM cd.facilities GROUP BY membercost HAVING count(*) > 1;
# Out:
#  * postgres://postgres:***@localhost/exercises
# 3 rows affected.
# [(Decimal('35'), 2), (Decimal('5'), 2), (Decimal('0'), 4)]

# %%
# %%sql
# -- 6th exercise
# SELECT * FROM cd.facilities WHERE facid in (0,5);
# Out:
#  * postgres://postgres:***@localhost/exercises
# 2 rows affected.
# [(0, 'Tennis Court 1', Decimal('5'), Decimal('25'), Decimal('10000'), Decimal('200')),
#  (5, 'Massage Room 2', Decimal('35'), Decimal('80'), Decimal('4000'), Decimal('3000'))]

# %% [markdown]
# Though above query is correct, the actual provided solution ran the following query -
#
# ```sql
#
# SELECT * FROM cd.facilities WHERE facid in (SELECT facid from cd.facilities);
# ```
#
# The inner query is called the subquery

# %%
# %%sql
# -- 7th exercise
# SELECT name, CASE WHEN monthlymaintenance > 100 THEN 'expensive' ELSE 'cheap' END AS cost FROM cd.facilities;
# Out:
#  * postgres://postgres:***@localhost/exercises
# 9 rows affected.
# [('Tennis Court 1', 'expensive'),
#  ('Tennis Court 2', 'expensive'),
#  ('Badminton Court', 'cheap'),
#  ('Table Tennis', 'cheap'),
#  ('Massage Room 1', 'expensive'),
#  ('Massage Room 2', 'expensive'),
#  ('Squash Court', 'cheap'),
#  ('Snooker Table', 'cheap'),
#  ('Pool Table', 'cheap')]

# %% [markdown]
# Note that we are doing computation in the area of the query  between `SELECT` and `FROM`. The syntax for this kind of query is -
#
# ```sql
# CASE expression
#
#     WHEN value1 THEN result1
#     WHEN value2 THEN result2
#     ---
#     ELSE result
#
# END
# ```
#
# Or
#
# ```sql
# CASE
#
#     WHEN condition1 THEN result1
#     WHEN condition2 THEN result2
#     ---
#     ELSE result
#
# END
# ```

# %%
# %%sql
# -- 8th exercise
# SELECT memid, surname, firstname, joindate
#     FROM cd.members WHERE joindate >= '2012-09-01';
# Out:
#  * postgres://postgres:***@localhost/exercises
# 10 rows affected.
# [(24, 'Sarwin', 'Ramnaresh', datetime.datetime(2012, 9, 1, 8, 44, 42)),
#  (26, 'Jones', 'Douglas', datetime.datetime(2012, 9, 2, 18, 43, 5)),
#  (27, 'Rumney', 'Henrietta', datetime.datetime(2012, 9, 5, 8, 42, 35)),
#  (28, 'Farrell', 'David', datetime.datetime(2012, 9, 15, 8, 22, 5)),
#  (29, 'Worthington-Smyth', 'Henry', datetime.datetime(2012, 9, 17, 12, 27, 15)),
#  (30, 'Purview', 'Millicent', datetime.datetime(2012, 9, 18, 19, 4, 1)),
#  (33, 'Tupperware', 'Hyacinth', datetime.datetime(2012, 9, 18, 19, 32, 5)),
#  (35, 'Hunt', 'John', datetime.datetime(2012, 9, 19, 11, 32, 45)),
#  (36, 'Crumpet', 'Erica', datetime.datetime(2012, 9, 22, 8, 36, 38)),
#  (37, 'Smith', 'Darren', datetime.datetime(2012, 9, 26, 18, 8, 45))]

# %% [markdown]
# SQL timestamps has the format of `YYYY-MM-DD HH:MM:SS:nnnnnn`. Althought we here provided only the date part, it was automatically cast into the full timestamp `2012-09-01 00:00:00`

# %%
# %%sql
# -- 9th exercise
# SELECT DISTINCT surname FROM cd.members ORDER BY surname LIMIT 10;
# Out:
#  * postgres://postgres:***@localhost/exercises
# 10 rows affected.
# [('Bader',),
#  ('Baker',),
#  ('Boothe',),
#  ('Butters',),
#  ('Coplin',),
#  ('Crumpet',),
#  ('Dare',),
#  ('Farrell',),
#  ('Genting',),
#  ('GUEST',)]

# %%
# %%sql
# -- 10th exercise- combine all surname from cd.members and all facilities name from cd.facilities in a single column
# SELECT surname FROM cd.members UNION SELECT name  FROM cd.facilities;
# Out:
#  * postgres://postgres:***@localhost/exercises
# 34 rows affected.
# [('Jones',),
#  ('GUEST',),
#  ('Table Tennis',),
#  ('Owen',),
#  ('Snooker Table',),
#  ('Tennis Court 1',),
#  ('Farrell',),
#  ('Boothe',),
#  ('Sarwin',),
#  ('Pool Table',),
#  ('Rumney',),
#  ('Stibbons',),
#  ('Joplette',),
#  ('Massage Room 2',),
#  ('Coplin',),
#  ('Purview',),
#  ('Genting',),
#  ('Baker',),
#  ('Rownam',),
#  ('Butters',),
#  ('Smith',),
#  ('Tupperware',),
#  ('Hunt',),
#  ('Tracy',),
#  ('Squash Court',),
#  ('Massage Room 1',),
#  ('Crumpet',),
#  ('Mackenzie',),
#  ('Bader',),
#  ('Dare',),
#  ('Pinker',),
#  ('Badminton Court',),
#  ('Worthington-Smyth',),
#  ('Tennis Court 2',)]

# %% [markdown]
# Use `UNION` when you care about duplicates. If you want duplicates as well, use `UNION ALL`

# %%
# %%sql
# -- 11th exercise - find out the signup date of last member. Column name should be 'latest'
# SELECT max(joindate) AS latest FROM cd.members;
# Out:
#  * postgres://postgres:***@localhost/exercises
# 1 rows affected.
# [(datetime.datetime(2012, 9, 26, 18, 8, 45),)]

# %%
# %%sql
# -- 12th exercise- get the first and last name of the last member who signed up - not just the date.
# SELECT firstname, surname, joindate FROM cd.members WHERE joindate = (SELECT max(joindate) FROM cd.members);
# Out:
#  * postgres://postgres:***@localhost/exercises
# 1 rows affected.
# [('Darren', 'Smith', datetime.datetime(2012, 9, 26, 18, 8, 45))]

# %% [markdown]
# You can get exact same result by running a query as shown below -

# %%
# %%sql
# -- 12th exercise- get the first and last name of the last member who signed up - not just the date.
# SELECT firstname, surname, joindate FROM cd.members ORDER BY joindate DESC LIMIT 1;
# Out:
#  * postgres://postgres:***@localhost/exercises
# 1 rows affected.
# [('Darren', 'Smith', datetime.datetime(2012, 9, 26, 18, 8, 45))]

# %%
# %%sql
# -- Part 2- 1st exercise
#
# SELECT starttime FROM cd.bookings bks INNER JOIN cd.members mems ON bks.memid = mems.memid
# WHERE mems.firstname = 'David' and mems.surname = 'Farrell' ;
# Out:
#  * postgres://postgres:***@localhost/exercises
# 34 rows affected.
# [(datetime.datetime(2012, 9, 18, 9, 0),),
#  (datetime.datetime(2012, 9, 18, 17, 30),),
#  (datetime.datetime(2012, 9, 18, 13, 30),),
#  (datetime.datetime(2012, 9, 18, 20, 0),),
#  (datetime.datetime(2012, 9, 19, 9, 30),),
#  (datetime.datetime(2012, 9, 19, 15, 0),),
#  (datetime.datetime(2012, 9, 19, 12, 0),),
#  (datetime.datetime(2012, 9, 20, 15, 30),),
#  (datetime.datetime(2012, 9, 20, 11, 30),),
#  (datetime.datetime(2012, 9, 20, 14, 0),),
#  (datetime.datetime(2012, 9, 21, 10, 30),),
#  (datetime.datetime(2012, 9, 21, 14, 0),),
#  (datetime.datetime(2012, 9, 22, 8, 30),),
#  (datetime.datetime(2012, 9, 22, 17, 0),),
#  (datetime.datetime(2012, 9, 23, 8, 30),),
#  (datetime.datetime(2012, 9, 23, 17, 30),),
#  (datetime.datetime(2012, 9, 23, 19, 0),),
#  (datetime.datetime(2012, 9, 24, 8, 0),),
#  (datetime.datetime(2012, 9, 24, 16, 30),),
#  (datetime.datetime(2012, 9, 24, 12, 30),),
#  (datetime.datetime(2012, 9, 25, 15, 30),),
#  (datetime.datetime(2012, 9, 25, 17, 0),),
#  (datetime.datetime(2012, 9, 26, 13, 0),),
#  (datetime.datetime(2012, 9, 26, 17, 0),),
#  (datetime.datetime(2012, 9, 27, 8, 0),),
#  (datetime.datetime(2012, 9, 28, 11, 30),),
#  (datetime.datetime(2012, 9, 28, 9, 30),),
#  (datetime.datetime(2012, 9, 28, 13, 0),),
#  (datetime.datetime(2012, 9, 29, 16, 0),),
#  (datetime.datetime(2012, 9, 29, 10, 30),),
#  (datetime.datetime(2012, 9, 29, 13, 30),),
#  (datetime.datetime(2012, 9, 29, 14, 30),),
#  (datetime.datetime(2012, 9, 29, 17, 30),),
#  (datetime.datetime(2012, 9, 30, 14, 30),)]

# %% [markdown]
# Few things to learn here. We are doing a 'joining' operation here. Other than `INNER JOIN`, we can also do `LEFT OUTER JOIN`, `RIGHT OUTER JOIN` or `FULL OUTER JOIN`. Also we join 2 tables based on some condition which is specified in `ON` clause. Here, for each value of `cd.bookings.memid`, we are looking for matching `memid` in `cd.members`. Let us see the results of this joining -

# %% [markdown]
# #### PART 2 - Joins and Subqueries

# %%
# %%sql
# -- Part 2- 1st exercise
#
# SELECT * FROM cd.bookings bks INNER JOIN cd.members mems ON bks.memid = mems.memid;
# Out:
#  * postgres://postgres:***@localhost/exercises
# 4044 rows affected.
# [(0, 3, 1, datetime.datetime(2012, 7, 3, 11, 0), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (1, 4, 1, datetime.datetime(2012, 7, 3, 8, 0), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (2, 6, 0, datetime.datetime(2012, 7, 3, 18, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (3, 7, 1, datetime.datetime(2012, 7, 3, 19, 0), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (4, 8, 1, datetime.datetime(2012, 7, 3, 10, 0), 1, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (5, 8, 1, datetime.datetime(2012, 7, 3, 15, 0), 1, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (6, 0, 2, datetime.datetime(2012, 7, 4, 9, 0), 3, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (7, 0, 2, datetime.datetime(2012, 7, 4, 15, 0), 3, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (8, 4, 3, datetime.datetime(2012, 7, 4, 13, 30), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (9, 4, 0, datetime.datetime(2012, 7, 4, 15, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (10, 4, 0, datetime.datetime(2012, 7, 4, 17, 30), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (11, 6, 0, datetime.datetime(2012, 7, 4, 12, 30), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (12, 6, 0, datetime.datetime(2012, 7, 4, 14, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (13, 6, 1, datetime.datetime(2012, 7, 4, 15, 30), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (14, 7, 2, datetime.datetime(2012, 7, 4, 14, 0), 2, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (15, 8, 2, datetime.datetime(2012, 7, 4, 12, 0), 1, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (16, 8, 3, datetime.datetime(2012, 7, 4, 18, 0), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (17, 1, 0, datetime.datetime(2012, 7, 5, 17, 30), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (18, 2, 1, datetime.datetime(2012, 7, 5, 9, 30), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (19, 3, 3, datetime.datetime(2012, 7, 5, 9, 0), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (20, 3, 1, datetime.datetime(2012, 7, 5, 19, 0), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (21, 4, 3, datetime.datetime(2012, 7, 5, 18, 30), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (22, 6, 0, datetime.datetime(2012, 7, 5, 13, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (23, 6, 1, datetime.datetime(2012, 7, 5, 14, 30), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (24, 7, 2, datetime.datetime(2012, 7, 5, 18, 30), 2, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (25, 8, 3, datetime.datetime(2012, 7, 5, 12, 30), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (26, 0, 0, datetime.datetime(2012, 7, 6, 8, 0), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (27, 0, 0, datetime.datetime(2012, 7, 6, 14, 0), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (28, 0, 2, datetime.datetime(2012, 7, 6, 15, 30), 3, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (29, 2, 1, datetime.datetime(2012, 7, 6, 17, 0), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (30, 3, 1, datetime.datetime(2012, 7, 6, 11, 0), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (31, 4, 3, datetime.datetime(2012, 7, 6, 12, 0), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (32, 6, 1, datetime.datetime(2012, 7, 6, 14, 0), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (33, 7, 2, datetime.datetime(2012, 7, 6, 8, 30), 2, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (34, 7, 2, datetime.datetime(2012, 7, 6, 13, 30), 2, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (35, 8, 3, datetime.datetime(2012, 7, 6, 15, 30), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (36, 0, 2, datetime.datetime(2012, 7, 7, 8, 30), 3, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (37, 0, 0, datetime.datetime(2012, 7, 7, 12, 30), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (38, 0, 2, datetime.datetime(2012, 7, 7, 14, 30), 3, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (39, 1, 3, datetime.datetime(2012, 7, 7, 8, 30), 3, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (40, 2, 1, datetime.datetime(2012, 7, 7, 9, 0), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (41, 2, 1, datetime.datetime(2012, 7, 7, 11, 30), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (42, 2, 1, datetime.datetime(2012, 7, 7, 16, 0), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (43, 3, 2, datetime.datetime(2012, 7, 7, 12, 30), 2, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (44, 4, 3, datetime.datetime(2012, 7, 7, 11, 30), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (45, 4, 3, datetime.datetime(2012, 7, 7, 14, 0), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (46, 4, 0, datetime.datetime(2012, 7, 7, 17, 30), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (47, 6, 0, datetime.datetime(2012, 7, 7, 8, 30), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (48, 6, 1, datetime.datetime(2012, 7, 7, 10, 30), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (49, 6, 1, datetime.datetime(2012, 7, 7, 14, 30), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (50, 6, 0, datetime.datetime(2012, 7, 7, 16, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (51, 7, 2, datetime.datetime(2012, 7, 7, 11, 30), 2, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (52, 8, 3, datetime.datetime(2012, 7, 7, 16, 0), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (53, 8, 3, datetime.datetime(2012, 7, 7, 17, 30), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (54, 0, 3, datetime.datetime(2012, 7, 8, 13, 0), 3, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (55, 0, 2, datetime.datetime(2012, 7, 8, 17, 30), 3, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (56, 1, 1, datetime.datetime(2012, 7, 8, 15, 0), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (57, 1, 1, datetime.datetime(2012, 7, 8, 17, 30), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (58, 3, 1, datetime.datetime(2012, 7, 8, 11, 30), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (59, 3, 3, datetime.datetime(2012, 7, 8, 18, 30), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (60, 3, 1, datetime.datetime(2012, 7, 8, 19, 30), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (61, 4, 0, datetime.datetime(2012, 7, 8, 11, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (62, 4, 2, datetime.datetime(2012, 7, 8, 16, 30), 2, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (63, 4, 0, datetime.datetime(2012, 7, 8, 18, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (64, 4, 0, datetime.datetime(2012, 7, 8, 19, 30), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (65, 6, 0, datetime.datetime(2012, 7, 8, 14, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (66, 6, 0, datetime.datetime(2012, 7, 8, 18, 30), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (67, 7, 2, datetime.datetime(2012, 7, 8, 11, 0), 2, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (68, 7, 1, datetime.datetime(2012, 7, 8, 16, 30), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (69, 8, 3, datetime.datetime(2012, 7, 8, 10, 0), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (70, 8, 3, datetime.datetime(2012, 7, 8, 16, 30), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (71, 0, 2, datetime.datetime(2012, 7, 9, 12, 30), 3, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (72, 0, 2, datetime.datetime(2012, 7, 9, 15, 30), 3, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (73, 0, 2, datetime.datetime(2012, 7, 9, 19, 0), 3, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (74, 1, 0, datetime.datetime(2012, 7, 9, 13, 0), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (75, 1, 1, datetime.datetime(2012, 7, 9, 19, 0), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (76, 2, 1, datetime.datetime(2012, 7, 9, 9, 0), 6, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (77, 2, 0, datetime.datetime(2012, 7, 9, 19, 0), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (78, 3, 3, datetime.datetime(2012, 7, 9, 17, 0), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (79, 3, 3, datetime.datetime(2012, 7, 9, 18, 30), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (80, 4, 2, datetime.datetime(2012, 7, 9, 11, 0), 2, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (81, 4, 3, datetime.datetime(2012, 7, 9, 14, 30), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (82, 6, 0, datetime.datetime(2012, 7, 9, 14, 30), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (83, 7, 1, datetime.datetime(2012, 7, 9, 15, 30), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (84, 7, 0, datetime.datetime(2012, 7, 9, 18, 30), 4, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (85, 8, 3, datetime.datetime(2012, 7, 9, 9, 30), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (86, 8, 3, datetime.datetime(2012, 7, 9, 16, 30), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (87, 8, 3, datetime.datetime(2012, 7, 9, 20, 0), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (88, 0, 0, datetime.datetime(2012, 7, 10, 11, 30), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (89, 0, 0, datetime.datetime(2012, 7, 10, 16, 0), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (90, 3, 2, datetime.datetime(2012, 7, 10, 8, 0), 2, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (91, 3, 1, datetime.datetime(2012, 7, 10, 11, 0), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (92, 3, 3, datetime.datetime(2012, 7, 10, 15, 30), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (93, 3, 2, datetime.datetime(2012, 7, 10, 16, 30), 2, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (94, 3, 1, datetime.datetime(2012, 7, 10, 18, 0), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (95, 4, 0, datetime.datetime(2012, 7, 10, 10, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (96, 4, 4, datetime.datetime(2012, 7, 10, 11, 30), 2, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (97, 4, 0, datetime.datetime(2012, 7, 10, 15, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (98, 4, 3, datetime.datetime(2012, 7, 10, 17, 0), 4, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (99, 5, 0, datetime.datetime(2012, 7, 10, 8, 30), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (100, 6, 0, datetime.datetime(2012, 7, 10, 14, 30), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (101, 6, 0, datetime.datetime(2012, 7, 10, 19, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (102, 7, 4, datetime.datetime(2012, 7, 10, 8, 30), 2, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (103, 7, 2, datetime.datetime(2012, 7, 10, 17, 30), 2, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (104, 8, 0, datetime.datetime(2012, 7, 10, 11, 30), 1, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (105, 8, 3, datetime.datetime(2012, 7, 10, 12, 0), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (106, 8, 3, datetime.datetime(2012, 7, 10, 19, 30), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (107, 0, 4, datetime.datetime(2012, 7, 11, 8, 0), 3, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (108, 0, 2, datetime.datetime(2012, 7, 11, 10, 0), 3, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (109, 0, 0, datetime.datetime(2012, 7, 11, 12, 0), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (110, 0, 0, datetime.datetime(2012, 7, 11, 14, 0), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (111, 0, 2, datetime.datetime(2012, 7, 11, 15, 30), 3, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (112, 0, 2, datetime.datetime(2012, 7, 11, 18, 30), 3, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (113, 1, 0, datetime.datetime(2012, 7, 11, 12, 30), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (114, 1, 0, datetime.datetime(2012, 7, 11, 16, 0), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (115, 4, 1, datetime.datetime(2012, 7, 11, 8, 0), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (116, 4, 0, datetime.datetime(2012, 7, 11, 9, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (117, 4, 3, datetime.datetime(2012, 7, 11, 11, 0), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (118, 4, 0, datetime.datetime(2012, 7, 11, 15, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (119, 5, 4, datetime.datetime(2012, 7, 11, 17, 0), 2, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (120, 6, 0, datetime.datetime(2012, 7, 11, 14, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (121, 6, 0, datetime.datetime(2012, 7, 11, 19, 30), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (122, 7, 0, datetime.datetime(2012, 7, 11, 8, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (123, 7, 0, datetime.datetime(2012, 7, 11, 14, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (124, 7, 0, datetime.datetime(2012, 7, 11, 16, 30), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (125, 8, 4, datetime.datetime(2012, 7, 11, 11, 0), 1, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (126, 8, 3, datetime.datetime(2012, 7, 11, 13, 0), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (127, 0, 0, datetime.datetime(2012, 7, 12, 13, 30), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (128, 0, 2, datetime.datetime(2012, 7, 12, 16, 30), 3, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (129, 1, 1, datetime.datetime(2012, 7, 12, 11, 30), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (130, 2, 1, datetime.datetime(2012, 7, 12, 9, 0), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (131, 2, 1, datetime.datetime(2012, 7, 12, 18, 30), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (132, 3, 3, datetime.datetime(2012, 7, 12, 18, 0), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (133, 4, 1, datetime.datetime(2012, 7, 12, 16, 0), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (134, 6, 0, datetime.datetime(2012, 7, 12, 12, 0), 4, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (135, 7, 2, datetime.datetime(2012, 7, 12, 8, 0), 2, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (136, 7, 4, datetime.datetime(2012, 7, 12, 13, 30), 2, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (137, 7, 4, datetime.datetime(2012, 7, 12, 16, 0), 2, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (138, 8, 3, datetime.datetime(2012, 7, 12, 16, 30), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (139, 0, 2, datetime.datetime(2012, 7, 13, 10, 30), 3, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (140, 0, 4, datetime.datetime(2012, 7, 13, 14, 0), 3, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (141, 0, 3, datetime.datetime(2012, 7, 13, 17, 0), 3, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (142, 1, 1, datetime.datetime(2012, 7, 13, 15, 0), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (143, 2, 1, datetime.datetime(2012, 7, 13, 9, 0), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (144, 2, 0, datetime.datetime(2012, 7, 13, 15, 0), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (145, 2, 1, datetime.datetime(2012, 7, 13, 16, 30), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (146, 4, 0, datetime.datetime(2012, 7, 13, 11, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (147, 4, 0, datetime.datetime(2012, 7, 13, 13, 30), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (148, 4, 0, datetime.datetime(2012, 7, 13, 15, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (149, 4, 3, datetime.datetime(2012, 7, 13, 16, 0), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (150, 4, 4, datetime.datetime(2012, 7, 13, 17, 30), 2, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (151, 6, 0, datetime.datetime(2012, 7, 13, 9, 30), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (152, 7, 0, datetime.datetime(2012, 7, 13, 8, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (153, 7, 1, datetime.datetime(2012, 7, 13, 11, 0), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (154, 7, 4, datetime.datetime(2012, 7, 13, 12, 30), 2, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (155, 8, 0, datetime.datetime(2012, 7, 13, 15, 30), 1, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (156, 8, 2, datetime.datetime(2012, 7, 13, 18, 30), 1, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (157, 0, 2, datetime.datetime(2012, 7, 14, 8, 30), 3, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (158, 0, 4, datetime.datetime(2012, 7, 14, 11, 30), 3, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (159, 0, 3, datetime.datetime(2012, 7, 14, 15, 0), 3, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (160, 1, 3, datetime.datetime(2012, 7, 14, 10, 30), 3, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (161, 1, 3, datetime.datetime(2012, 7, 14, 12, 30), 3, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (162, 1, 0, datetime.datetime(2012, 7, 14, 14, 30), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (163, 2, 1, datetime.datetime(2012, 7, 14, 8, 30), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (164, 3, 2, datetime.datetime(2012, 7, 14, 16, 0), 2, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (165, 4, 3, datetime.datetime(2012, 7, 14, 8, 0), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (166, 4, 1, datetime.datetime(2012, 7, 14, 14, 30), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (167, 6, 0, datetime.datetime(2012, 7, 14, 9, 30), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (168, 6, 1, datetime.datetime(2012, 7, 14, 12, 30), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (169, 6, 0, datetime.datetime(2012, 7, 14, 15, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (170, 7, 2, datetime.datetime(2012, 7, 14, 12, 30), 2, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (171, 7, 2, datetime.datetime(2012, 7, 14, 15, 0), 2, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (172, 7, 4, datetime.datetime(2012, 7, 14, 16, 30), 2, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (173, 7, 1, datetime.datetime(2012, 7, 14, 19, 0), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (174, 8, 3, datetime.datetime(2012, 7, 14, 9, 0), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (175, 8, 1, datetime.datetime(2012, 7, 14, 17, 0), 1, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (176, 0, 2, datetime.datetime(2012, 7, 15, 8, 0), 3, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (177, 0, 0, datetime.datetime(2012, 7, 15, 16, 0), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (178, 0, 2, datetime.datetime(2012, 7, 15, 19, 0), 3, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (179, 1, 0, datetime.datetime(2012, 7, 15, 10, 0), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (180, 1, 0, datetime.datetime(2012, 7, 15, 12, 0), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (181, 1, 3, datetime.datetime(2012, 7, 15, 15, 30), 3, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (182, 2, 1, datetime.datetime(2012, 7, 15, 13, 0), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (183, 3, 1, datetime.datetime(2012, 7, 15, 17, 30), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (184, 4, 3, datetime.datetime(2012, 7, 15, 11, 30), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (185, 4, 0, datetime.datetime(2012, 7, 15, 15, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (186, 4, 3, datetime.datetime(2012, 7, 15, 17, 30), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (187, 7, 4, datetime.datetime(2012, 7, 15, 14, 30), 2, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (188, 7, 4, datetime.datetime(2012, 7, 15, 17, 0), 2, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (189, 8, 4, datetime.datetime(2012, 7, 15, 10, 0), 1, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (190, 8, 2, datetime.datetime(2012, 7, 15, 12, 0), 1, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (191, 8, 3, datetime.datetime(2012, 7, 15, 12, 30), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (192, 8, 3, datetime.datetime(2012, 7, 15, 13, 30), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (193, 0, 5, datetime.datetime(2012, 7, 16, 11, 0), 3, 5, 'Butters', 'Gerald', '1065 Huntingdon Avenue, Boston', 56754, '(844) 078-4130', 1, datetime.datetime(2012, 7, 9, 10, 44, 9)),
#  (194, 0, 5, datetime.datetime(2012, 7, 16, 19, 0), 3, 5, 'Butters', 'Gerald', '1065 Huntingdon Avenue, Boston', 56754, '(844) 078-4130', 1, datetime.datetime(2012, 7, 9, 10, 44, 9)),
#  (195, 1, 1, datetime.datetime(2012, 7, 16, 8, 0), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (196, 1, 0, datetime.datetime(2012, 7, 16, 12, 30), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (197, 2, 1, datetime.datetime(2012, 7, 16, 16, 30), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (198, 4, 3, datetime.datetime(2012, 7, 16, 9, 0), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (199, 4, 1, datetime.datetime(2012, 7, 16, 11, 0), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (200, 4, 3, datetime.datetime(2012, 7, 16, 12, 0), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (201, 4, 3, datetime.datetime(2012, 7, 16, 17, 30), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (202, 6, 0, datetime.datetime(2012, 7, 16, 18, 30), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (203, 7, 4, datetime.datetime(2012, 7, 16, 8, 0), 2, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (204, 7, 2, datetime.datetime(2012, 7, 16, 11, 30), 2, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (205, 7, 4, datetime.datetime(2012, 7, 16, 12, 30), 2, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (206, 7, 5, datetime.datetime(2012, 7, 16, 14, 0), 2, 5, 'Butters', 'Gerald', '1065 Huntingdon Avenue, Boston', 56754, '(844) 078-4130', 1, datetime.datetime(2012, 7, 9, 10, 44, 9)),
#  (207, 8, 4, datetime.datetime(2012, 7, 16, 12, 0), 1, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (208, 8, 1, datetime.datetime(2012, 7, 16, 15, 0), 1, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (209, 8, 4, datetime.datetime(2012, 7, 16, 18, 0), 1, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (210, 8, 3, datetime.datetime(2012, 7, 16, 19, 30), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (211, 0, 5, datetime.datetime(2012, 7, 17, 12, 30), 3, 5, 'Butters', 'Gerald', '1065 Huntingdon Avenue, Boston', 56754, '(844) 078-4130', 1, datetime.datetime(2012, 7, 9, 10, 44, 9)),
#  (212, 0, 5, datetime.datetime(2012, 7, 17, 18, 0), 3, 5, 'Butters', 'Gerald', '1065 Huntingdon Avenue, Boston', 56754, '(844) 078-4130', 1, datetime.datetime(2012, 7, 9, 10, 44, 9)),
#  (213, 1, 1, datetime.datetime(2012, 7, 17, 10, 0), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (214, 1, 4, datetime.datetime(2012, 7, 17, 14, 30), 3, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (215, 2, 5, datetime.datetime(2012, 7, 17, 10, 30), 3, 5, 'Butters', 'Gerald', '1065 Huntingdon Avenue, Boston', 56754, '(844) 078-4130', 1, datetime.datetime(2012, 7, 9, 10, 44, 9)),
#  (216, 2, 1, datetime.datetime(2012, 7, 17, 12, 30), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (217, 2, 1, datetime.datetime(2012, 7, 17, 15, 30), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (218, 2, 2, datetime.datetime(2012, 7, 17, 19, 0), 3, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (219, 3, 1, datetime.datetime(2012, 7, 17, 14, 0), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (220, 3, 2, datetime.datetime(2012, 7, 17, 15, 0), 2, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (221, 4, 0, datetime.datetime(2012, 7, 17, 9, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (222, 4, 3, datetime.datetime(2012, 7, 17, 10, 30), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (223, 4, 3, datetime.datetime(2012, 7, 17, 12, 0), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (224, 4, 5, datetime.datetime(2012, 7, 17, 16, 0), 2, 5, 'Butters', 'Gerald', '1065 Huntingdon Avenue, Boston', 56754, '(844) 078-4130', 1, datetime.datetime(2012, 7, 9, 10, 44, 9)),
#  (225, 4, 3, datetime.datetime(2012, 7, 17, 18, 30), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (226, 5, 0, datetime.datetime(2012, 7, 17, 13, 30), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (227, 6, 4, datetime.datetime(2012, 7, 17, 12, 0), 2, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (228, 6, 0, datetime.datetime(2012, 7, 17, 14, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (229, 7, 4, datetime.datetime(2012, 7, 17, 8, 0), 2, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (230, 7, 5, datetime.datetime(2012, 7, 17, 14, 0), 2, 5, 'Butters', 'Gerald', '1065 Huntingdon Avenue, Boston', 56754, '(844) 078-4130', 1, datetime.datetime(2012, 7, 9, 10, 44, 9)),
#  (231, 7, 4, datetime.datetime(2012, 7, 17, 16, 0), 2, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (232, 8, 3, datetime.datetime(2012, 7, 17, 8, 30), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (233, 8, 2, datetime.datetime(2012, 7, 17, 11, 0), 1, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (234, 8, 3, datetime.datetime(2012, 7, 17, 11, 30), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (235, 8, 3, datetime.datetime(2012, 7, 17, 14, 30), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (236, 8, 0, datetime.datetime(2012, 7, 17, 15, 0), 1, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (237, 8, 3, datetime.datetime(2012, 7, 17, 15, 30), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (238, 8, 3, datetime.datetime(2012, 7, 17, 18, 0), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (239, 8, 3, datetime.datetime(2012, 7, 17, 20, 0), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (240, 0, 5, datetime.datetime(2012, 7, 18, 13, 0), 3, 5, 'Butters', 'Gerald', '1065 Huntingdon Avenue, Boston', 56754, '(844) 078-4130', 1, datetime.datetime(2012, 7, 9, 10, 44, 9)),
#  (241, 0, 5, datetime.datetime(2012, 7, 18, 17, 30), 3, 5, 'Butters', 'Gerald', '1065 Huntingdon Avenue, Boston', 56754, '(844) 078-4130', 1, datetime.datetime(2012, 7, 9, 10, 44, 9)),
#  (242, 1, 0, datetime.datetime(2012, 7, 18, 14, 0), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (243, 1, 0, datetime.datetime(2012, 7, 18, 16, 30), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (244, 2, 1, datetime.datetime(2012, 7, 18, 14, 0), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (245, 3, 2, datetime.datetime(2012, 7, 18, 11, 30), 2, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (246, 3, 3, datetime.datetime(2012, 7, 18, 19, 0), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (247, 4, 1, datetime.datetime(2012, 7, 18, 8, 30), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (248, 4, 4, datetime.datetime(2012, 7, 18, 10, 0), 2, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (249, 4, 5, datetime.datetime(2012, 7, 18, 19, 0), 2, 5, 'Butters', 'Gerald', '1065 Huntingdon Avenue, Boston', 56754, '(844) 078-4130', 1, datetime.datetime(2012, 7, 9, 10, 44, 9)),
#  (250, 5, 0, datetime.datetime(2012, 7, 18, 14, 30), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (251, 6, 0, datetime.datetime(2012, 7, 18, 10, 30), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (252, 6, 0, datetime.datetime(2012, 7, 18, 13, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (253, 6, 0, datetime.datetime(2012, 7, 18, 15, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (254, 6, 1, datetime.datetime(2012, 7, 18, 19, 30), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (255, 7, 4, datetime.datetime(2012, 7, 18, 8, 30), 2, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (256, 7, 4, datetime.datetime(2012, 7, 18, 11, 0), 2, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (257, 8, 3, datetime.datetime(2012, 7, 18, 11, 0), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (258, 8, 0, datetime.datetime(2012, 7, 18, 13, 0), 1, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (259, 8, 3, datetime.datetime(2012, 7, 18, 14, 30), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (260, 8, 4, datetime.datetime(2012, 7, 18, 16, 0), 1, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (261, 8, 3, datetime.datetime(2012, 7, 18, 16, 30), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (262, 8, 4, datetime.datetime(2012, 7, 18, 20, 0), 1, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (263, 0, 2, datetime.datetime(2012, 7, 19, 8, 30), 3, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (264, 0, 4, datetime.datetime(2012, 7, 19, 10, 30), 3, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (265, 0, 5, datetime.datetime(2012, 7, 19, 12, 0), 3, 5, 'Butters', 'Gerald', '1065 Huntingdon Avenue, Boston', 56754, '(844) 078-4130', 1, datetime.datetime(2012, 7, 9, 10, 44, 9)),
#  (266, 0, 0, datetime.datetime(2012, 7, 19, 13, 30), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (267, 0, 5, datetime.datetime(2012, 7, 19, 16, 30), 3, 5, 'Butters', 'Gerald', '1065 Huntingdon Avenue, Boston', 56754, '(844) 078-4130', 1, datetime.datetime(2012, 7, 9, 10, 44, 9)),
#  (268, 1, 1, datetime.datetime(2012, 7, 19, 11, 30), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (269, 1, 0, datetime.datetime(2012, 7, 19, 15, 0), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (270, 1, 0, datetime.datetime(2012, 7, 19, 18, 30), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (271, 2, 1, datetime.datetime(2012, 7, 19, 9, 30), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (272, 2, 0, datetime.datetime(2012, 7, 19, 11, 30), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (273, 2, 1, datetime.datetime(2012, 7, 19, 14, 30), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (274, 2, 2, datetime.datetime(2012, 7, 19, 16, 0), 3, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (275, 3, 3, datetime.datetime(2012, 7, 19, 8, 30), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (276, 3, 3, datetime.datetime(2012, 7, 19, 17, 0), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (277, 3, 3, datetime.datetime(2012, 7, 19, 18, 30), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (278, 4, 3, datetime.datetime(2012, 7, 19, 12, 0), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (279, 4, 5, datetime.datetime(2012, 7, 19, 14, 30), 2, 5, 'Butters', 'Gerald', '1065 Huntingdon Avenue, Boston', 56754, '(844) 078-4130', 1, datetime.datetime(2012, 7, 9, 10, 44, 9)),
#  (280, 4, 0, datetime.datetime(2012, 7, 19, 16, 30), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (281, 4, 1, datetime.datetime(2012, 7, 19, 18, 30), 2, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
# ...
#  (909, 8, 0, datetime.datetime(2012, 8, 7, 11, 0), 1, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (910, 8, 3, datetime.datetime(2012, 8, 7, 12, 0), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (911, 8, 2, datetime.datetime(2012, 8, 7, 12, 30), 1, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (912, 8, 2, datetime.datetime(2012, 8, 7, 14, 30), 1, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (913, 8, 0, datetime.datetime(2012, 8, 7, 16, 30), 1, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (914, 8, 3, datetime.datetime(2012, 8, 7, 17, 0), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (915, 8, 8, datetime.datetime(2012, 8, 7, 19, 30), 1, 8, 'Boothe', 'Tim', '3 Bloomsbury Close, Reading, 00234', 234, '(811) 433-2547', 3, datetime.datetime(2012, 7, 25, 16, 2, 35)),
#  (916, 0, 10, datetime.datetime(2012, 8, 8, 9, 0), 3, 10, 'Owen', 'Charles', '52 Cheshire Grove, Winchester, 28563', 28563, '(855) 542-5251', 1, datetime.datetime(2012, 8, 3, 19, 42, 37)),
#  (917, 0, 6, datetime.datetime(2012, 8, 8, 12, 30), 3, 6, 'Tracy', 'Burton', '3 Tunisia Drive, Boston', 45678, '(822) 354-9973', None, datetime.datetime(2012, 7, 15, 8, 52, 55)),
#  (918, 0, 5, datetime.datetime(2012, 8, 8, 14, 0), 3, 5, 'Butters', 'Gerald', '1065 Huntingdon Avenue, Boston', 56754, '(844) 078-4130', 1, datetime.datetime(2012, 7, 9, 10, 44, 9)),
#  (919, 0, 6, datetime.datetime(2012, 8, 8, 16, 30), 3, 6, 'Tracy', 'Burton', '3 Tunisia Drive, Boston', 45678, '(822) 354-9973', None, datetime.datetime(2012, 7, 15, 8, 52, 55)),
#  (920, 1, 0, datetime.datetime(2012, 8, 8, 8, 30), 6, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (921, 1, 10, datetime.datetime(2012, 8, 8, 11, 30), 3, 10, 'Owen', 'Charles', '52 Cheshire Grove, Winchester, 28563', 28563, '(855) 542-5251', 1, datetime.datetime(2012, 8, 3, 19, 42, 37)),
#  (922, 1, 10, datetime.datetime(2012, 8, 8, 14, 0), 3, 10, 'Owen', 'Charles', '52 Cheshire Grove, Winchester, 28563', 28563, '(855) 542-5251', 1, datetime.datetime(2012, 8, 3, 19, 42, 37)),
#  (923, 1, 9, datetime.datetime(2012, 8, 8, 19, 0), 3, 9, 'Stibbons', 'Ponder', '5 Dragons Way, Winchester', 87630, '(833) 160-3900', 6, datetime.datetime(2012, 7, 25, 17, 9, 5)),
#  (924, 2, 5, datetime.datetime(2012, 8, 8, 8, 0), 3, 5, 'Butters', 'Gerald', '1065 Huntingdon Avenue, Boston', 56754, '(844) 078-4130', 1, datetime.datetime(2012, 7, 9, 10, 44, 9)),
#  (925, 2, 9, datetime.datetime(2012, 8, 8, 9, 30), 3, 9, 'Stibbons', 'Ponder', '5 Dragons Way, Winchester', 87630, '(833) 160-3900', 6, datetime.datetime(2012, 7, 25, 17, 9, 5)),
#  (926, 2, 7, datetime.datetime(2012, 8, 8, 11, 0), 3, 7, 'Dare', 'Nancy', '6 Hunting Lodge Way, Boston', 10383, '(833) 776-4001', 4, datetime.datetime(2012, 7, 25, 8, 59, 12)),
#  (927, 2, 1, datetime.datetime(2012, 8, 8, 14, 0), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (928, 2, 5, datetime.datetime(2012, 8, 8, 17, 30), 3, 5, 'Butters', 'Gerald', '1065 Huntingdon Avenue, Boston', 56754, '(844) 078-4130', 1, datetime.datetime(2012, 7, 9, 10, 44, 9)),
#  (929, 2, 1, datetime.datetime(2012, 8, 8, 19, 0), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (930, 3, 10, datetime.datetime(2012, 8, 8, 8, 0), 2, 10, 'Owen', 'Charles', '52 Cheshire Grove, Winchester, 28563', 28563, '(855) 542-5251', 1, datetime.datetime(2012, 8, 3, 19, 42, 37)),
#  (931, 3, 6, datetime.datetime(2012, 8, 8, 10, 0), 2, 6, 'Tracy', 'Burton', '3 Tunisia Drive, Boston', 45678, '(822) 354-9973', None, datetime.datetime(2012, 7, 15, 8, 52, 55)),
#  (932, 3, 0, datetime.datetime(2012, 8, 8, 12, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (933, 3, 10, datetime.datetime(2012, 8, 8, 15, 30), 2, 10, 'Owen', 'Charles', '52 Cheshire Grove, Winchester, 28563', 28563, '(855) 542-5251', 1, datetime.datetime(2012, 8, 3, 19, 42, 37)),
#  (934, 3, 2, datetime.datetime(2012, 8, 8, 19, 0), 2, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (935, 4, 6, datetime.datetime(2012, 8, 8, 8, 0), 2, 6, 'Tracy', 'Burton', '3 Tunisia Drive, Boston', 45678, '(822) 354-9973', None, datetime.datetime(2012, 7, 15, 8, 52, 55)),
#  (936, 4, 8, datetime.datetime(2012, 8, 8, 11, 0), 2, 8, 'Boothe', 'Tim', '3 Bloomsbury Close, Reading, 00234', 234, '(811) 433-2547', 3, datetime.datetime(2012, 7, 25, 16, 2, 35)),
#  (937, 4, 9, datetime.datetime(2012, 8, 8, 12, 30), 4, 9, 'Stibbons', 'Ponder', '5 Dragons Way, Winchester', 87630, '(833) 160-3900', 6, datetime.datetime(2012, 7, 25, 17, 9, 5)),
#  (938, 4, 0, datetime.datetime(2012, 8, 8, 15, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (939, 4, 0, datetime.datetime(2012, 8, 8, 16, 30), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (940, 4, 3, datetime.datetime(2012, 8, 8, 17, 30), 2, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (941, 5, 0, datetime.datetime(2012, 8, 8, 8, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (942, 6, 0, datetime.datetime(2012, 8, 8, 9, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (943, 6, 0, datetime.datetime(2012, 8, 8, 11, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (944, 6, 8, datetime.datetime(2012, 8, 8, 12, 30), 2, 8, 'Boothe', 'Tim', '3 Bloomsbury Close, Reading, 00234', 234, '(811) 433-2547', 3, datetime.datetime(2012, 7, 25, 16, 2, 35)),
#  (945, 6, 6, datetime.datetime(2012, 8, 8, 15, 0), 2, 6, 'Tracy', 'Burton', '3 Tunisia Drive, Boston', 45678, '(822) 354-9973', None, datetime.datetime(2012, 7, 15, 8, 52, 55)),
#  (946, 6, 10, datetime.datetime(2012, 8, 8, 17, 30), 2, 10, 'Owen', 'Charles', '52 Cheshire Grove, Winchester, 28563', 28563, '(855) 542-5251', 1, datetime.datetime(2012, 8, 3, 19, 42, 37)),
#  (947, 6, 0, datetime.datetime(2012, 8, 8, 19, 0), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (948, 7, 8, datetime.datetime(2012, 8, 8, 8, 0), 2, 8, 'Boothe', 'Tim', '3 Bloomsbury Close, Reading, 00234', 234, '(811) 433-2547', 3, datetime.datetime(2012, 7, 25, 16, 2, 35)),
#  (949, 7, 9, datetime.datetime(2012, 8, 8, 11, 0), 2, 9, 'Stibbons', 'Ponder', '5 Dragons Way, Winchester', 87630, '(833) 160-3900', 6, datetime.datetime(2012, 7, 25, 17, 9, 5)),
#  (950, 7, 7, datetime.datetime(2012, 8, 8, 12, 30), 2, 7, 'Dare', 'Nancy', '6 Hunting Lodge Way, Boston', 10383, '(833) 776-4001', 4, datetime.datetime(2012, 7, 25, 8, 59, 12)),
#  (951, 7, 4, datetime.datetime(2012, 8, 8, 14, 0), 2, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (952, 7, 9, datetime.datetime(2012, 8, 8, 15, 30), 2, 9, 'Stibbons', 'Ponder', '5 Dragons Way, Winchester', 87630, '(833) 160-3900', 6, datetime.datetime(2012, 7, 25, 17, 9, 5)),
#  (953, 7, 10, datetime.datetime(2012, 8, 8, 18, 30), 2, 10, 'Owen', 'Charles', '52 Cheshire Grove, Winchester, 28563', 28563, '(855) 542-5251', 1, datetime.datetime(2012, 8, 3, 19, 42, 37)),
#  (954, 8, 4, datetime.datetime(2012, 8, 8, 8, 0), 1, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (955, 8, 2, datetime.datetime(2012, 8, 8, 9, 0), 1, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (956, 8, 3, datetime.datetime(2012, 8, 8, 10, 0), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (957, 8, 3, datetime.datetime(2012, 8, 8, 11, 0), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (958, 8, 3, datetime.datetime(2012, 8, 8, 12, 0), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (959, 8, 2, datetime.datetime(2012, 8, 8, 13, 0), 1, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (960, 8, 7, datetime.datetime(2012, 8, 8, 16, 0), 1, 7, 'Dare', 'Nancy', '6 Hunting Lodge Way, Boston', 10383, '(833) 776-4001', 4, datetime.datetime(2012, 7, 25, 8, 59, 12)),
#  (961, 8, 1, datetime.datetime(2012, 8, 8, 16, 30), 1, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (962, 8, 3, datetime.datetime(2012, 8, 8, 17, 0), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (963, 8, 2, datetime.datetime(2012, 8, 8, 17, 30), 1, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (964, 8, 1, datetime.datetime(2012, 8, 8, 18, 30), 1, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (965, 0, 6, datetime.datetime(2012, 8, 9, 9, 30), 3, 6, 'Tracy', 'Burton', '3 Tunisia Drive, Boston', 45678, '(822) 354-9973', None, datetime.datetime(2012, 7, 15, 8, 52, 55)),
#  (966, 0, 7, datetime.datetime(2012, 8, 9, 16, 0), 3, 7, 'Dare', 'Nancy', '6 Hunting Lodge Way, Boston', 10383, '(833) 776-4001', 4, datetime.datetime(2012, 7, 25, 8, 59, 12)),
#  (967, 0, 10, datetime.datetime(2012, 8, 9, 17, 30), 3, 10, 'Owen', 'Charles', '52 Cheshire Grove, Winchester, 28563', 28563, '(855) 542-5251', 1, datetime.datetime(2012, 8, 3, 19, 42, 37)),
#  (968, 1, 10, datetime.datetime(2012, 8, 9, 8, 0), 3, 10, 'Owen', 'Charles', '52 Cheshire Grove, Winchester, 28563', 28563, '(855) 542-5251', 1, datetime.datetime(2012, 8, 3, 19, 42, 37)),
#  (969, 1, 0, datetime.datetime(2012, 8, 9, 10, 0), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (970, 1, 8, datetime.datetime(2012, 8, 9, 14, 0), 3, 8, 'Boothe', 'Tim', '3 Bloomsbury Close, Reading, 00234', 234, '(811) 433-2547', 3, datetime.datetime(2012, 7, 25, 16, 2, 35)),
#  (971, 1, 0, datetime.datetime(2012, 8, 9, 17, 0), 3, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (972, 2, 2, datetime.datetime(2012, 8, 9, 9, 0), 3, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (973, 2, 1, datetime.datetime(2012, 8, 9, 11, 0), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (974, 2, 9, datetime.datetime(2012, 8, 9, 13, 0), 3, 9, 'Stibbons', 'Ponder', '5 Dragons Way, Winchester', 87630, '(833) 160-3900', 6, datetime.datetime(2012, 7, 25, 17, 9, 5)),
#  (975, 2, 1, datetime.datetime(2012, 8, 9, 14, 30), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (976, 2, 1, datetime.datetime(2012, 8, 9, 16, 30), 3, 1, 'Smith', 'Darren', '8 Bloomsbury Close, Boston', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 2, 5)),
#  (977, 3, 10, datetime.datetime(2012, 8, 9, 10, 0), 2, 10, 'Owen', 'Charles', '52 Cheshire Grove, Winchester, 28563', 28563, '(855) 542-5251', 1, datetime.datetime(2012, 8, 3, 19, 42, 37)),
#  (978, 3, 7, datetime.datetime(2012, 8, 9, 13, 30), 2, 7, 'Dare', 'Nancy', '6 Hunting Lodge Way, Boston', 10383, '(833) 776-4001', 4, datetime.datetime(2012, 7, 25, 8, 59, 12)),
#  (979, 3, 6, datetime.datetime(2012, 8, 9, 14, 30), 2, 6, 'Tracy', 'Burton', '3 Tunisia Drive, Boston', 45678, '(822) 354-9973', None, datetime.datetime(2012, 7, 15, 8, 52, 55)),
#  (980, 3, 2, datetime.datetime(2012, 8, 9, 18, 0), 2, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (981, 4, 0, datetime.datetime(2012, 8, 9, 9, 0), 4, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (982, 4, 0, datetime.datetime(2012, 8, 9, 12, 0), 4, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (983, 4, 10, datetime.datetime(2012, 8, 9, 16, 30), 2, 10, 'Owen', 'Charles', '52 Cheshire Grove, Winchester, 28563', 28563, '(855) 542-5251', 1, datetime.datetime(2012, 8, 3, 19, 42, 37)),
#  (984, 4, 9, datetime.datetime(2012, 8, 9, 17, 30), 2, 9, 'Stibbons', 'Ponder', '5 Dragons Way, Winchester', 87630, '(833) 160-3900', 6, datetime.datetime(2012, 7, 25, 17, 9, 5)),
#  (985, 4, 8, datetime.datetime(2012, 8, 9, 18, 30), 2, 8, 'Boothe', 'Tim', '3 Bloomsbury Close, Reading, 00234', 234, '(811) 433-2547', 3, datetime.datetime(2012, 7, 25, 16, 2, 35)),
#  (986, 4, 10, datetime.datetime(2012, 8, 9, 19, 30), 2, 10, 'Owen', 'Charles', '52 Cheshire Grove, Winchester, 28563', 28563, '(855) 542-5251', 1, datetime.datetime(2012, 8, 3, 19, 42, 37)),
#  (987, 6, 6, datetime.datetime(2012, 8, 9, 11, 30), 2, 6, 'Tracy', 'Burton', '3 Tunisia Drive, Boston', 45678, '(822) 354-9973', None, datetime.datetime(2012, 7, 15, 8, 52, 55)),
#  (988, 6, 6, datetime.datetime(2012, 8, 9, 18, 30), 2, 6, 'Tracy', 'Burton', '3 Tunisia Drive, Boston', 45678, '(822) 354-9973', None, datetime.datetime(2012, 7, 15, 8, 52, 55)),
#  (989, 7, 8, datetime.datetime(2012, 8, 9, 8, 0), 2, 8, 'Boothe', 'Tim', '3 Bloomsbury Close, Reading, 00234', 234, '(811) 433-2547', 3, datetime.datetime(2012, 7, 25, 16, 2, 35)),
#  (990, 7, 8, datetime.datetime(2012, 8, 9, 10, 30), 2, 8, 'Boothe', 'Tim', '3 Bloomsbury Close, Reading, 00234', 234, '(811) 433-2547', 3, datetime.datetime(2012, 7, 25, 16, 2, 35)),
#  (991, 7, 0, datetime.datetime(2012, 8, 9, 12, 30), 2, 0, 'GUEST', 'GUEST', 'GUEST', 0, '(000) 000-0000', None, datetime.datetime(2012, 7, 1, 0, 0)),
#  (992, 7, 6, datetime.datetime(2012, 8, 9, 16, 0), 2, 6, 'Tracy', 'Burton', '3 Tunisia Drive, Boston', 45678, '(822) 354-9973', None, datetime.datetime(2012, 7, 15, 8, 52, 55)),
#  (993, 7, 2, datetime.datetime(2012, 8, 9, 17, 0), 2, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (994, 7, 4, datetime.datetime(2012, 8, 9, 18, 30), 2, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (995, 8, 4, datetime.datetime(2012, 8, 9, 10, 0), 1, 4, 'Joplette', 'Janice', '20 Crossing Road, New York', 234, '(833) 942-4710', 1, datetime.datetime(2012, 7, 3, 10, 25, 5)),
#  (996, 8, 2, datetime.datetime(2012, 8, 9, 11, 30), 1, 2, 'Smith', 'Tracy', '8 Bloomsbury Close, New York', 4321, '555-555-5555', None, datetime.datetime(2012, 7, 2, 12, 8, 23)),
#  (997, 8, 6, datetime.datetime(2012, 8, 9, 13, 0), 1, 6, 'Tracy', 'Burton', '3 Tunisia Drive, Boston', 45678, '(822) 354-9973', None, datetime.datetime(2012, 7, 15, 8, 52, 55)),
#  (998, 8, 3, datetime.datetime(2012, 8, 9, 15, 0), 1, 3, 'Rownam', 'Tim', '23 Highway Way, Boston', 23423, '(844) 693-0723', None, datetime.datetime(2012, 7, 3, 9, 32, 15)),
#  (999, 8, 5, datetime.datetime(2012, 8, 9, 15, 30), 1, 5, 'Butters', 'Gerald', '1065 Huntingdon Avenue, Boston', 56754, '(844) 078-4130', 1, datetime.datetime(2012, 7, 9, 10, 44, 9)),
#  ...]

# %% [markdown]
# Above you can see the combined table resulted from joining operation. Notice that values of `memid` and `memid_1` are equal for any given row. Also notice the use of aliases `bks` and `mems` for respective tables.
#
# One more thing, since both table have a column with same name `memid`, we can differentiate between those columns by using the `.` notation.
#
# Finally our orignal query can also be written as follows -

# %%
# %%sql
# -- Part 2- 1st exercise
#
# SELECT
# starttime FROM cd.bookings bks ,cd.members mems
# WHERE
# mems.firstname = 'David'
# and mems.surname = 'Farrell'
# and mems.memid = bks.memid;
# Out:
#  * postgres://postgres:***@localhost/exercises
# 34 rows affected.
# [(datetime.datetime(2012, 9, 18, 9, 0),),
#  (datetime.datetime(2012, 9, 18, 17, 30),),
#  (datetime.datetime(2012, 9, 18, 13, 30),),
#  (datetime.datetime(2012, 9, 18, 20, 0),),
#  (datetime.datetime(2012, 9, 19, 9, 30),),
#  (datetime.datetime(2012, 9, 19, 15, 0),),
#  (datetime.datetime(2012, 9, 19, 12, 0),),
#  (datetime.datetime(2012, 9, 20, 15, 30),),
#  (datetime.datetime(2012, 9, 20, 11, 30),),
#  (datetime.datetime(2012, 9, 20, 14, 0),),
#  (datetime.datetime(2012, 9, 21, 10, 30),),
#  (datetime.datetime(2012, 9, 21, 14, 0),),
#  (datetime.datetime(2012, 9, 22, 8, 30),),
#  (datetime.datetime(2012, 9, 22, 17, 0),),
#  (datetime.datetime(2012, 9, 23, 8, 30),),
#  (datetime.datetime(2012, 9, 23, 17, 30),),
#  (datetime.datetime(2012, 9, 23, 19, 0),),
#  (datetime.datetime(2012, 9, 24, 8, 0),),
#  (datetime.datetime(2012, 9, 24, 16, 30),),
#  (datetime.datetime(2012, 9, 24, 12, 30),),
#  (datetime.datetime(2012, 9, 25, 15, 30),),
#  (datetime.datetime(2012, 9, 25, 17, 0),),
#  (datetime.datetime(2012, 9, 26, 13, 0),),
#  (datetime.datetime(2012, 9, 26, 17, 0),),
#  (datetime.datetime(2012, 9, 27, 8, 0),),
#  (datetime.datetime(2012, 9, 28, 11, 30),),
#  (datetime.datetime(2012, 9, 28, 9, 30),),
#  (datetime.datetime(2012, 9, 28, 13, 0),),
#  (datetime.datetime(2012, 9, 29, 16, 0),),
#  (datetime.datetime(2012, 9, 29, 10, 30),),
#  (datetime.datetime(2012, 9, 29, 13, 30),),
#  (datetime.datetime(2012, 9, 29, 14, 30),),
#  (datetime.datetime(2012, 9, 29, 17, 30),),
#  (datetime.datetime(2012, 9, 30, 14, 30),)]

# %%
# %%sql
# -- Part 2- 2nd exercise
#
# SELECT bks.starttime, fac.name FROM cd.bookings bks, cd.facilities fac
# WHERE bks.starttime >= '2012-09-21'
# AND bks.starttime < '2012-09-22'
# AND fac.name LIKE 'Tennis%'
# AND bks.facid = fac.facid
# ORDER BY bks.starttime;
# Out:
#  * postgres://postgres:***@localhost/exercises
# 12 rows affected.
# [(datetime.datetime(2012, 9, 21, 8, 0), 'Tennis Court 1'),
#  (datetime.datetime(2012, 9, 21, 8, 0), 'Tennis Court 2'),
#  (datetime.datetime(2012, 9, 21, 9, 30), 'Tennis Court 1'),
#  (datetime.datetime(2012, 9, 21, 10, 0), 'Tennis Court 2'),
#  (datetime.datetime(2012, 9, 21, 11, 30), 'Tennis Court 2'),
#  (datetime.datetime(2012, 9, 21, 12, 0), 'Tennis Court 1'),
#  (datetime.datetime(2012, 9, 21, 13, 30), 'Tennis Court 1'),
#  (datetime.datetime(2012, 9, 21, 14, 0), 'Tennis Court 2'),
#  (datetime.datetime(2012, 9, 21, 15, 30), 'Tennis Court 1'),
#  (datetime.datetime(2012, 9, 21, 16, 0), 'Tennis Court 2'),
#  (datetime.datetime(2012, 9, 21, 17, 0), 'Tennis Court 1'),
#  (datetime.datetime(2012, 9, 21, 18, 0), 'Tennis Court 2')]

# %% [markdown]
# Answer in the source material was -
#
# ```
# SELECT bks.starttime AS START, fac.name AS name
# FROM
# cd.facilities facs INNER JOIN cd.bookings bks ON facs.facid = bks.facid
# WHERE
# facs.facid IN (0,1) AND bks.starttime >= '2012-09-21' AND bks.starttime < '2012-09-21'
# ORDER BY bks.starttime;
# ```

# %%
# %%sql
# -- Part 2- 3 exercise - list out members who recommended others. No duplicates. Order by (surname, firstname)
#
# SELECT DISTINCT mem1.firstname, mem1.surname FROM cd.members mem1 INNER JOIN cd.members mem2
# ON mem1.memid = mem2.recommendedby
# ORDER BY mem1.surname, mem1.firstname;
# Out:
#  * postgres://postgres:***@localhost/exercises
# 13 rows affected.
# [('Florence', 'Bader'),
#  ('Timothy', 'Baker'),
#  ('Gerald', 'Butters'),
#  ('Jemima', 'Farrell'),
#  ('Matthew', 'Genting'),
#  ('David', 'Jones'),
#  ('Janice', 'Joplette'),
#  ('Millicent', 'Purview'),
#  ('Tim', 'Rownam'),
#  ('Darren', 'Smith'),
#  ('Tracy', 'Smith'),
#  ('Ponder', 'Stibbons'),
#  ('Burton', 'Tracy')]

# %%
# %%sql
# -- Part 2- 4th exercise
# /* How can you output a list of all members, including the individual who recommended them (if any)? Ensure that results
# are ordered by (surname, firstname)
# */
# SELECT mem1.firstname AS name, mem1.surname AS surname, mem2.firstname AS rec_name, mem2.surname AS rec_surname
# FROM cd.members mem1 LEFT OUTER JOIN cd.members mem2
# ON mem2.memid = mem1.recommendedby
# ORDER BY surname, name;
# Out:
#  * postgres://postgres:***@localhost/exercises
# 31 rows affected.
# [('Florence', 'Bader', 'Ponder', 'Stibbons'),
#  ('Anne', 'Baker', 'Ponder', 'Stibbons'),
#  ('Timothy', 'Baker', 'Jemima', 'Farrell'),
#  ('Tim', 'Boothe', 'Tim', 'Rownam'),
#  ('Gerald', 'Butters', 'Darren', 'Smith'),
#  ('Joan', 'Coplin', 'Timothy', 'Baker'),
#  ('Erica', 'Crumpet', 'Tracy', 'Smith'),
#  ('Nancy', 'Dare', 'Janice', 'Joplette'),
#  ('David', 'Farrell', None, None),
#  ('Jemima', 'Farrell', None, None),
#  ('Matthew', 'Genting', 'Gerald', 'Butters'),
#  ('GUEST', 'GUEST', None, None),
#  ('John', 'Hunt', 'Millicent', 'Purview'),
#  ('David', 'Jones', 'Janice', 'Joplette'),
#  ('Douglas', 'Jones', 'David', 'Jones'),
#  ('Janice', 'Joplette', 'Darren', 'Smith'),
#  ('Anna', 'Mackenzie', 'Darren', 'Smith'),
#  ('Charles', 'Owen', 'Darren', 'Smith'),
#  ('David', 'Pinker', 'Jemima', 'Farrell'),
#  ('Millicent', 'Purview', 'Tracy', 'Smith'),
#  ('Tim', 'Rownam', None, None),
#  ('Henrietta', 'Rumney', 'Matthew', 'Genting'),
#  ('Ramnaresh', 'Sarwin', 'Florence', 'Bader'),
#  ('Darren', 'Smith', None, None),
#  ('Darren', 'Smith', None, None),
#  ('Jack', 'Smith', 'Darren', 'Smith'),
#  ('Tracy', 'Smith', None, None),
#  ('Ponder', 'Stibbons', 'Burton', 'Tracy'),
#  ('Burton', 'Tracy', None, None),
#  ('Hyacinth', 'Tupperware', None, None),
#  ('Henry', 'Worthington-Smyth', 'Tracy', 'Smith')]

# %%
# %%sql
# -- Part 2- 5th exercise
# /*Produce a list of all members who have used a tennis court? Output should have name of the court, and the name of member
# formatted as a single column. No duplicate data, order by member name
# */
#
# SELECT DISTINCT mems.firstname || ' ' || mems.surname AS member, facs.name AS facility
# FROM cd.members mems INNER JOIN cd.bookings bks ON mems.memid = bks.memid
# INNER JOIN cd.facilities facs ON bks.facid = facs.facid
# WHERE bks.facid IN (0,1)
# ORDER BY member;
# Out:
#  * postgres://postgres:***@localhost/exercises
# 46 rows affected.
# [('Anne Baker', 'Tennis Court 1'),
#  ('Anne Baker', 'Tennis Court 2'),
#  ('Burton Tracy', 'Tennis Court 1'),
#  ('Burton Tracy', 'Tennis Court 2'),
#  ('Charles Owen', 'Tennis Court 1'),
#  ('Charles Owen', 'Tennis Court 2'),
#  ('Darren Smith', 'Tennis Court 2'),
#  ('David Farrell', 'Tennis Court 1'),
#  ('David Farrell', 'Tennis Court 2'),
#  ('David Jones', 'Tennis Court 2'),
#  ('David Jones', 'Tennis Court 1'),
#  ('David Pinker', 'Tennis Court 1'),
#  ('Douglas Jones', 'Tennis Court 1'),
#  ('Erica Crumpet', 'Tennis Court 1'),
#  ('Florence Bader', 'Tennis Court 2'),
#  ('Florence Bader', 'Tennis Court 1'),
#  ('Gerald Butters', 'Tennis Court 2'),
#  ('Gerald Butters', 'Tennis Court 1'),
#  ('GUEST GUEST', 'Tennis Court 2'),
#  ('GUEST GUEST', 'Tennis Court 1'),
#  ('Henrietta Rumney', 'Tennis Court 2'),
#  ('Jack Smith', 'Tennis Court 1'),
#  ('Jack Smith', 'Tennis Court 2'),
#  ('Janice Joplette', 'Tennis Court 1'),
#  ('Janice Joplette', 'Tennis Court 2'),
#  ('Jemima Farrell', 'Tennis Court 1'),
#  ('Jemima Farrell', 'Tennis Court 2'),
#  ('Joan Coplin', 'Tennis Court 1'),
#  ('John Hunt', 'Tennis Court 2'),
#  ('John Hunt', 'Tennis Court 1'),
#  ('Matthew Genting', 'Tennis Court 1'),
#  ('Millicent Purview', 'Tennis Court 2'),
#  ('Nancy Dare', 'Tennis Court 1'),
#  ('Nancy Dare', 'Tennis Court 2'),
#  ('Ponder Stibbons', 'Tennis Court 1'),
#  ('Ponder Stibbons', 'Tennis Court 2'),
#  ('Ramnaresh Sarwin', 'Tennis Court 1'),
#  ('Ramnaresh Sarwin', 'Tennis Court 2'),
#  ('Tim Boothe', 'Tennis Court 1'),
#  ('Tim Boothe', 'Tennis Court 2'),
#  ('Tim Rownam', 'Tennis Court 2'),
#  ('Tim Rownam', 'Tennis Court 1'),
#  ('Timothy Baker', 'Tennis Court 1'),
#  ('Timothy Baker', 'Tennis Court 2'),
#  ('Tracy Smith', 'Tennis Court 1'),
#  ('Tracy Smith', 'Tennis Court 2')]

# %%
# %%sql
# -- Part 2- 6th exercise
# /*Produce a list of bookings on the day of '2012-09-14' which will cost the member (or guest) more than 30$? Remember that
# guests have different costs to members (the listed costs are per half hour slot), and the guest user is always ID 0. Include
# in your output the name of facility, the name of member formatted as a single column, and the cost. Order by descending cost,
# and don't use subqueries
# */
#
# SELECT mems.firstname || ' ' || mems.surname AS member, facs.name AS facility,
# CASE
# WHEN mems.memid = 0 THEN bks.slots*facs.guestcost
# ELSE bks.slots*facs.membercost
# END AS cost
# FROM cd.members mems INNER JOIN cd.bookings bks ON mems.memid = bks.memid
# INNER JOIN cd.facilities facs ON bks.facid = facs.facid
# WHERE
# bks.starttime >= '2012-09-14' AND
# bks.starttime < '2012-09-15' AND (
# (mems.memid = 0 AND bks.slots*facs.guestcost > 30) OR
# (mems.memid != 0 AND bks.slots*facs.membercost > 30) )
# ORDER BY cost DESC;
# Out:
#  * postgres://postgres:***@localhost/exercises
# 18 rows affected.
# [('GUEST GUEST', 'Massage Room 2', Decimal('320')),
#  ('GUEST GUEST', 'Massage Room 1', Decimal('160')),
#  ('GUEST GUEST', 'Massage Room 1', Decimal('160')),
#  ('GUEST GUEST', 'Massage Room 1', Decimal('160')),
#  ('GUEST GUEST', 'Tennis Court 2', Decimal('150')),
#  ('Jemima Farrell', 'Massage Room 1', Decimal('140')),
#  ('GUEST GUEST', 'Tennis Court 1', Decimal('75')),
#  ('GUEST GUEST', 'Tennis Court 2', Decimal('75')),
#  ('GUEST GUEST', 'Tennis Court 1', Decimal('75')),
#  ('Matthew Genting', 'Massage Room 1', Decimal('70')),
#  ('Florence Bader', 'Massage Room 2', Decimal('70')),
#  ('GUEST GUEST', 'Squash Court', Decimal('70.0')),
#  ('Jemima Farrell', 'Massage Room 1', Decimal('70')),
#  ('Ponder Stibbons', 'Massage Room 1', Decimal('70')),
#  ('Burton Tracy', 'Massage Room 1', Decimal('70')),
#  ('Jack Smith', 'Massage Room 1', Decimal('70')),
#  ('GUEST GUEST', 'Squash Court', Decimal('35.0')),
#  ('GUEST GUEST', 'Squash Court', Decimal('35.0'))]

# %%
# %%sql
# -- Part 2- 7th exercise - find out list of members and their recommenders without using joins.
#
# SELECT DISTINCT mems.firstname || ' ' || mems.surname AS member,
# (SELECT recs.firstname || ' ' || recs.surname AS recommender
# FROM cd.members recs WHERE recs.memid = mems.recommendedby )
# FROM cd.members mems
# ORDER by member;
# Out:
#  * postgres://postgres:***@localhost/exercises
# 30 rows affected.
# [('Anna Mackenzie', 'Darren Smith'),
#  ('Anne Baker', 'Ponder Stibbons'),
#  ('Burton Tracy', None),
#  ('Charles Owen', 'Darren Smith'),
#  ('Darren Smith', None),
#  ('David Farrell', None),
#  ('David Jones', 'Janice Joplette'),
#  ('David Pinker', 'Jemima Farrell'),
#  ('Douglas Jones', 'David Jones'),
#  ('Erica Crumpet', 'Tracy Smith'),
#  ('Florence Bader', 'Ponder Stibbons'),
#  ('Gerald Butters', 'Darren Smith'),
#  ('GUEST GUEST', None),
#  ('Henrietta Rumney', 'Matthew Genting'),
#  ('Henry Worthington-Smyth', 'Tracy Smith'),
#  ('Hyacinth Tupperware', None),
#  ('Jack Smith', 'Darren Smith'),
#  ('Janice Joplette', 'Darren Smith'),
#  ('Jemima Farrell', None),
#  ('Joan Coplin', 'Timothy Baker'),
#  ('John Hunt', 'Millicent Purview'),
#  ('Matthew Genting', 'Gerald Butters'),
#  ('Millicent Purview', 'Tracy Smith'),
#  ('Nancy Dare', 'Janice Joplette'),
#  ('Ponder Stibbons', 'Burton Tracy'),
#  ('Ramnaresh Sarwin', 'Florence Bader'),
#  ('Tim Boothe', 'Tim Rownam'),
#  ('Tim Rownam', None),
#  ('Timothy Baker', 'Jemima Farrell'),
#  ('Tracy Smith', None)]

# %% [markdown]
# Above in 6th exercise of Part 2, we produced the list of costly bookings by using a bit messy query. Below is the another
# version to produce the same result -

# %%
# %%sql
# -- Part 2- 8th exercise
#
# SELECT member, facility, cost FROM (
# SELECT  mems.firstname || ' ' || mems.surname AS member, facs.name AS facility,
# CASE WHEN mems.memid = 0 THEN bks.slots*facs.guestcost
# ELSE bks.slots*facs.membercost
# END AS cost
# FROM cd.members mems INNER JOIN cd.bookings bks ON mems.memid = bks.memid
# INNER JOIN cd.facilities facs ON bks.facid = facs.facid
# WHERE bks.starttime >= '2012-09-14'
# AND bks.starttime < '2012-09-15') AS bookings
# WHERE cost > 30 ORDER BY cost DESC;
# Out:
#  * postgres://postgres:***@localhost/exercises
# 18 rows affected.
# [('GUEST GUEST', 'Massage Room 2', Decimal('320')),
#  ('GUEST GUEST', 'Massage Room 1', Decimal('160')),
#  ('GUEST GUEST', 'Massage Room 1', Decimal('160')),
#  ('GUEST GUEST', 'Massage Room 1', Decimal('160')),
#  ('GUEST GUEST', 'Tennis Court 2', Decimal('150')),
#  ('Jemima Farrell', 'Massage Room 1', Decimal('140')),
#  ('GUEST GUEST', 'Tennis Court 1', Decimal('75')),
#  ('GUEST GUEST', 'Tennis Court 2', Decimal('75')),
#  ('GUEST GUEST', 'Tennis Court 1', Decimal('75')),
#  ('Matthew Genting', 'Massage Room 1', Decimal('70')),
#  ('Florence Bader', 'Massage Room 2', Decimal('70')),
#  ('GUEST GUEST', 'Squash Court', Decimal('70.0')),
#  ('Jemima Farrell', 'Massage Room 1', Decimal('70')),
#  ('Ponder Stibbons', 'Massage Room 1', Decimal('70')),
#  ('Burton Tracy', 'Massage Room 1', Decimal('70')),
#  ('Jack Smith', 'Massage Room 1', Decimal('70')),
#  ('GUEST GUEST', 'Squash Court', Decimal('35.0')),
#  ('GUEST GUEST', 'Squash Court', Decimal('35.0'))]

# %% [markdown]
# #### PART 3 - Modifying Data

# %%
# %%sql
# -- 1
# INSERT INTO cd.facilities VALUES (9, 'Spa', 20,30,100000, 800);
# SELECT * FROM cd.facilities;
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 10 rows affected.
# [(0, 'Tennis Court 1', Decimal('5'), Decimal('25'), Decimal('10000'), Decimal('200')),
#  (1, 'Tennis Court 2', Decimal('5'), Decimal('25'), Decimal('8000'), Decimal('200')),
#  (2, 'Badminton Court', Decimal('0'), Decimal('15.5'), Decimal('4000'), Decimal('50')),
#  (3, 'Table Tennis', Decimal('0'), Decimal('5'), Decimal('320'), Decimal('10')),
#  (4, 'Massage Room 1', Decimal('35'), Decimal('80'), Decimal('4000'), Decimal('3000')),
#  (5, 'Massage Room 2', Decimal('35'), Decimal('80'), Decimal('4000'), Decimal('3000')),
#  (6, 'Squash Court', Decimal('3.5'), Decimal('17.5'), Decimal('5000'), Decimal('80')),
#  (7, 'Snooker Table', Decimal('0'), Decimal('5'), Decimal('450'), Decimal('15')),
#  (8, 'Pool Table', Decimal('0'), Decimal('5'), Decimal('400'), Decimal('15')),
#  (9, 'Spa', Decimal('20'), Decimal('30'), Decimal('100000'), Decimal('800'))]

# %%
# %%sql
# --2 trivial query but the alternative solution is worth noting
#
# INSERT INTO cd.facilities SELECT 10, 'Spa 2', 20,30, 100000, 800
# UNION ALL SELECT 11, 'Squash Court 2', 3.5, 17.5, 5000, 80;
#
# SELECT * FROM cd.facilities;
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 2 rows affected.
# 12 rows affected.
# [(0, 'Tennis Court 1', Decimal('5'), Decimal('25'), Decimal('10000'), Decimal('200')),
#  (1, 'Tennis Court 2', Decimal('5'), Decimal('25'), Decimal('8000'), Decimal('200')),
#  (2, 'Badminton Court', Decimal('0'), Decimal('15.5'), Decimal('4000'), Decimal('50')),
#  (3, 'Table Tennis', Decimal('0'), Decimal('5'), Decimal('320'), Decimal('10')),
#  (4, 'Massage Room 1', Decimal('35'), Decimal('80'), Decimal('4000'), Decimal('3000')),
#  (5, 'Massage Room 2', Decimal('35'), Decimal('80'), Decimal('4000'), Decimal('3000')),
#  (6, 'Squash Court', Decimal('3.5'), Decimal('17.5'), Decimal('5000'), Decimal('80')),
#  (7, 'Snooker Table', Decimal('0'), Decimal('5'), Decimal('450'), Decimal('15')),
#  (8, 'Pool Table', Decimal('0'), Decimal('5'), Decimal('400'), Decimal('15')),
#  (9, 'Spa', Decimal('20'), Decimal('30'), Decimal('100000'), Decimal('800')),
#  (10, 'Spa 2', Decimal('20'), Decimal('30'), Decimal('100000'), Decimal('800')),
#  (11, 'Squash Court 2', Decimal('3.5'), Decimal('17.5'), Decimal('5000'), Decimal('80'))]

# %% [markdown]
# Above, we could have used `INSET INTO <table> VALUES (..), (...)` but alternative way may also be useful sometimes as we'll see next. In particular, you can supply only constant values when inserting values via `VALUES ()` method.

# %%
# %%sql
# --3
#
# INSERT INTO cd.facilities
# SELECT (SELECT max(facid) FROM cd.facilities)+1, 'Spa 3', 20,30,100000, 800;
# SELECT * FROM cd.facilities;
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 1 rows affected.
# 13 rows affected.
# [(0, 'Tennis Court 1', Decimal('5'), Decimal('25'), Decimal('10000'), Decimal('200')),
#  (1, 'Tennis Court 2', Decimal('5'), Decimal('25'), Decimal('8000'), Decimal('200')),
#  (2, 'Badminton Court', Decimal('0'), Decimal('15.5'), Decimal('4000'), Decimal('50')),
#  (3, 'Table Tennis', Decimal('0'), Decimal('5'), Decimal('320'), Decimal('10')),
#  (4, 'Massage Room 1', Decimal('35'), Decimal('80'), Decimal('4000'), Decimal('3000')),
#  (5, 'Massage Room 2', Decimal('35'), Decimal('80'), Decimal('4000'), Decimal('3000')),
#  (6, 'Squash Court', Decimal('3.5'), Decimal('17.5'), Decimal('5000'), Decimal('80')),
#  (7, 'Snooker Table', Decimal('0'), Decimal('5'), Decimal('450'), Decimal('15')),
#  (8, 'Pool Table', Decimal('0'), Decimal('5'), Decimal('400'), Decimal('15')),
#  (9, 'Spa', Decimal('20'), Decimal('30'), Decimal('100000'), Decimal('800')),
#  (10, 'Spa 2', Decimal('20'), Decimal('30'), Decimal('100000'), Decimal('800')),
#  (11, 'Squash Court 2', Decimal('3.5'), Decimal('17.5'), Decimal('5000'), Decimal('80')),
#  (12, 'Spa 3', Decimal('20'), Decimal('30'), Decimal('100000'), Decimal('800'))]

# %% [markdown]
# Note that we didn't use `...VALUES (...)` method here because we needed to calculate `facid` which we couldn't do in `..VALUES (...)` as this method only take constant values.

# %%
# %%sql
# --4
#
# UPDATE cd.facilities SET initialoutlay = 10000 WHERE name = 'Tennis Court 2';
# SELECT * FROM cd.facilities;
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 1 rows affected.
# 13 rows affected.
# [(0, 'Tennis Court 1', Decimal('5'), Decimal('25'), Decimal('10000'), Decimal('200')),
#  (2, 'Badminton Court', Decimal('0'), Decimal('15.5'), Decimal('4000'), Decimal('50')),
#  (3, 'Table Tennis', Decimal('0'), Decimal('5'), Decimal('320'), Decimal('10')),
#  (4, 'Massage Room 1', Decimal('35'), Decimal('80'), Decimal('4000'), Decimal('3000')),
#  (5, 'Massage Room 2', Decimal('35'), Decimal('80'), Decimal('4000'), Decimal('3000')),
#  (6, 'Squash Court', Decimal('3.5'), Decimal('17.5'), Decimal('5000'), Decimal('80')),
#  (7, 'Snooker Table', Decimal('0'), Decimal('5'), Decimal('450'), Decimal('15')),
#  (8, 'Pool Table', Decimal('0'), Decimal('5'), Decimal('400'), Decimal('15')),
#  (9, 'Spa', Decimal('20'), Decimal('30'), Decimal('100000'), Decimal('800')),
#  (10, 'Spa 2', Decimal('20'), Decimal('30'), Decimal('100000'), Decimal('800')),
#  (11, 'Squash Court 2', Decimal('3.5'), Decimal('17.5'), Decimal('5000'), Decimal('80')),
#  (12, 'Spa 3', Decimal('20'), Decimal('30'), Decimal('100000'), Decimal('800')),
#  (1, 'Tennis Court 2', Decimal('5'), Decimal('25'), Decimal('10000'), Decimal('200'))]

# %%
# %%sql
# --5
#
# UPDATE cd.facilities SET membercost =  6, guestcost = 30 WHERE facid in (0,1);
# SELECT * FROM cd.facilities;
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 2 rows affected.
# 13 rows affected.
# [(2, 'Badminton Court', Decimal('0'), Decimal('15.5'), Decimal('4000'), Decimal('50')),
#  (3, 'Table Tennis', Decimal('0'), Decimal('5'), Decimal('320'), Decimal('10')),
#  (4, 'Massage Room 1', Decimal('35'), Decimal('80'), Decimal('4000'), Decimal('3000')),
#  (5, 'Massage Room 2', Decimal('35'), Decimal('80'), Decimal('4000'), Decimal('3000')),
#  (6, 'Squash Court', Decimal('3.5'), Decimal('17.5'), Decimal('5000'), Decimal('80')),
#  (7, 'Snooker Table', Decimal('0'), Decimal('5'), Decimal('450'), Decimal('15')),
#  (8, 'Pool Table', Decimal('0'), Decimal('5'), Decimal('400'), Decimal('15')),
#  (9, 'Spa', Decimal('20'), Decimal('30'), Decimal('100000'), Decimal('800')),
#  (10, 'Spa 2', Decimal('20'), Decimal('30'), Decimal('100000'), Decimal('800')),
#  (11, 'Squash Court 2', Decimal('3.5'), Decimal('17.5'), Decimal('5000'), Decimal('80')),
#  (12, 'Spa 3', Decimal('20'), Decimal('30'), Decimal('100000'), Decimal('800')),
#  (0, 'Tennis Court 1', Decimal('6'), Decimal('30'), Decimal('10000'), Decimal('200')),
#  (1, 'Tennis Court 2', Decimal('6'), Decimal('30'), Decimal('10000'), Decimal('200'))]

# %%
# %%sql
# --6
#
# UPDATE cd.facilities SET membercost = (SELECT membercost FROM cd.facilities WHERE facid = 0)*1.1,
# guestcost = (SELECT guestcost FROM cd.facilities WHERE facid = 0)*1.1 WHERE facid = 1;
# SELECT * FROM cd.facilities;
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 1 rows affected.
# 13 rows affected.
# [(2, 'Badminton Court', Decimal('0'), Decimal('15.5'), Decimal('4000'), Decimal('50')),
#  (3, 'Table Tennis', Decimal('0'), Decimal('5'), Decimal('320'), Decimal('10')),
#  (4, 'Massage Room 1', Decimal('35'), Decimal('80'), Decimal('4000'), Decimal('3000')),
#  (5, 'Massage Room 2', Decimal('35'), Decimal('80'), Decimal('4000'), Decimal('3000')),
#  (6, 'Squash Court', Decimal('3.5'), Decimal('17.5'), Decimal('5000'), Decimal('80')),
#  (7, 'Snooker Table', Decimal('0'), Decimal('5'), Decimal('450'), Decimal('15')),
#  (8, 'Pool Table', Decimal('0'), Decimal('5'), Decimal('400'), Decimal('15')),
#  (9, 'Spa', Decimal('20'), Decimal('30'), Decimal('100000'), Decimal('800')),
#  (10, 'Spa 2', Decimal('20'), Decimal('30'), Decimal('100000'), Decimal('800')),
#  (11, 'Squash Court 2', Decimal('3.5'), Decimal('17.5'), Decimal('5000'), Decimal('80')),
#  (12, 'Spa 3', Decimal('20'), Decimal('30'), Decimal('100000'), Decimal('800')),
#  (0, 'Tennis Court 1', Decimal('6'), Decimal('30'), Decimal('10000'), Decimal('200')),
#  (1, 'Tennis Court 2', Decimal('6.6'), Decimal('33.0'), Decimal('10000'), Decimal('200'))]

# %%
# %%sql
# --6 more elegant solution
#
# UPDATE cd.facilities facs
# SET membercost = facs2.membercost*1.1,
# guestcost = facs2.guestcost*1.1
# FROM (SELECT * FROM cd.facilities WHERE facid = 0) facs2
# WHERE facs.facid = 1;`

# %% [markdown]
# #### PART 4 - Aggregation

# %%
# %%sql
# -- 1 counting the number of facilities
#
# SELECT count(name) FROM cd.facilities;
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(13,)]

# %% [markdown]
# ```
# COUNT(*) -- simply returns the number of rows
# COUNT(address) -- counts the number of non-null addresses
# COUNT(DISTINCT address) -- count the number of different addresses
# ```
#
# To count each facility, you may wish to try out something like this -
#
# ```
# SELECT facid, COUNT(*) FROM cd.facilities;
# ```
# But it won't work. Following is the way -

# %%
# %%sql
#
# SELECT facid, (SELECT COUNT(*) FROM cd.facilities) FROM cd.facilities;
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 13 rows affected.
# [(2, 13),
#  (3, 13),
#  (4, 13),
#  (5, 13),
#  (6, 13),
#  (7, 13),
#  (8, 13),
#  (9, 13),
#  (10, 13),
#  (11, 13),
#  (12, 13),
#  (0, 13),
#  (1, 13)]

# %%
# %%sql
# --2 count the facilities which has cost to guest more than or equal to 10
#
# SELECT COUNT(*) FROM cd.facilities WHERE guestcost >= 10;
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(10,)]

# %%
# %%sql
# --3 produce a count of the number of recommendations each member has made. Order by member
#
# SELECT recommendedby, COUNT(recommendedby) FROM cd.members WHERE recommendedby IS NOT NULL
# GROUP BY recommendedby ORDER BY recommendedby;
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 13 rows affected.
# [(1, 5),
#  (2, 3),
#  (3, 1),
#  (4, 2),
#  (5, 1),
#  (6, 1),
#  (9, 2),
#  (11, 1),
#  (13, 2),
#  (15, 1),
#  (16, 1),
#  (20, 1),
#  (30, 1)]

# %%
# %%sql
#
# --4 total no of slots booked per facility
# SELECT facid, SUM(slots) FROM cd.bookings GROUP BY facid ORDER BY facid;
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 9 rows affected.
# [(0, 1320),
#  (1, 1278),
#  (2, 1209),
#  (3, 830),
#  (4, 1404),
#  (5, 228),
#  (6, 1104),
#  (7, 908),
#  (8, 911)]

# %%
# %%sql
# -- 5 total no of slots booked per facility in a given month, order by number of slots
#
# SELECT facid, SUM(slots) FROM cd.bookings WHERE starttime >= '2012-09-01' AND starttime < '2012-10-02'
# GROUP BY facid ORDER BY SUM(slots);
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 9 rows affected.
# [(5, 122),
#  (3, 422),
#  (7, 426),
#  (8, 471),
#  (6, 540),
#  (2, 570),
#  (1, 588),
#  (0, 591),
#  (4, 648)]

# %%
# %%sql
# --6 find the list of the total no of slots booked per facility per month in the year 2012. Sorted by facid and month
#
# SELECT facid, EXTRACT(MONTH FROM starttime) AS month, SUM(slots) AS "Total Slots" FROM cd.bookings -- ' ' does not work
# WHERE starttime >= '2012-01-01' AND starttime <'2013-01-01'
# GROUP BY facid, month ORDER BY facid, month;
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 27 rows affected.
# [(0, 7.0, 270),
#  (0, 8.0, 459),
#  (0, 9.0, 591),
#  (1, 7.0, 207),
#  (1, 8.0, 483),
#  (1, 9.0, 588),
#  (2, 7.0, 180),
#  (2, 8.0, 459),
#  (2, 9.0, 570),
#  (3, 7.0, 104),
#  (3, 8.0, 304),
#  (3, 9.0, 422),
#  (4, 7.0, 264),
#  (4, 8.0, 492),
#  (4, 9.0, 648),
#  (5, 7.0, 24),
#  (5, 8.0, 82),
#  (5, 9.0, 122),
#  (6, 7.0, 164),
#  (6, 8.0, 400),
#  (6, 9.0, 540),
#  (7, 7.0, 156),
#  (7, 8.0, 326),
#  (7, 9.0, 426),
#  (8, 7.0, 117),
#  (8, 8.0, 322),
#  (8, 9.0, 471)]

# %% [markdown]
# **`EXTRACT` function**  - This fxn allows us to get individual components of a timestamp.
# Also look for `DATE_TRUNC` which truncates a date to a given granularity

# %%
# %%sql
#
# --7 find the count of members who have made at least one booking
#
# SELECT COUNT(DISTINCT memid) FROM cd.bookings
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(30,)]

# %%
# %%sql
# --alternative query for problem 7
# SELECT COUNT(*) FROM (SELECT DISTINCT memid FROM cd.bookings) AS mems -- AS mems part is necessary. Why?
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(30,)]

# %%
# %%sql
# -- 8 List of facilities with more than 1000 slots booked
# SELECT facid, SUM(slots) FROM cd.bookings GROUP BY facid HAVING SUM(slots) > 1000
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 5 rows affected.
# [(6, 1104), (0, 1320), (4, 1404), (2, 1209), (1, 1278)]

# %%
# %%sql
# --9 find the total revenue of each facility
# -- look carefully at solution
#
# SELECT facs.name, SUM(slots * CASE
#                      WHEN memid = 0 THEN facs.guestcost
#                      ELSE facs.membercost END) AS revenue
# FROM cd.bookings bks INNER JOIN cd.facilities facs
# ON bks.facid = facs.facid GROUP BY facs.name ORDER BY revenue;
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 9 rows affected.
# [('Table Tennis', Decimal('180')),
#  ('Snooker Table', Decimal('240')),
#  ('Pool Table', Decimal('270')),
#  ('Badminton Court', Decimal('1906.5')),
#  ('Squash Court', Decimal('13468.0')),
#  ('Massage Room 2', Decimal('15810')),
#  ('Tennis Court 1', Decimal('16632')),
#  ('Tennis Court 2', Decimal('18889.2')),
#  ('Massage Room 1', Decimal('72540'))]

# %%
# %%sql
# --10 find facilities with total revenue less than 1000
# -- see the source section for more discussion
# SELECT name, revenue FROM (
# SELECT facs.name, SUM(CASE
#                      WHEN memid = 0 THEN slots*facs.guestcost
#                      ELSE slots*membercost
#                      END) AS revenue
# FROM cd.bookings bks INNER JOIN cd.facilities facs ON bks.facid = facs.facid
# GROUP BY facs.name) AS agg WHERE revenue < 1000
# ORDER BY revenue;
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 3 rows affected.
# [('Table Tennis', Decimal('180')),
#  ('Snooker Table', Decimal('240')),
#  ('Pool Table', Decimal('270'))]

# %%
# %%sql
# --11 output facility id that has the highest number of slots booked
# -- see relevant source for more
#
# SELECT facid, SUM(slots) as "Total Slots" FROM cd.bookings GROUP BY facid ORDER BY SUM(slots) DESC LIMIT 1;
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(4, 1404)]

# %% [markdown]
# ##### Common Table Expressions
#
# Alternate solution for problem 11

# %%
# %%sql
# -- 11 alternate solution using CTE
#
#
# WITH sum AS (SELECT facid, SUM(slots) AS totalslots FROM cd.bookings
# GROUP BY facid)
# SELECT facid, totalslots FROM sum WHERE totalslots = (SELECT MAX(totalslots) FROM sum);
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(4, 1404)]

# %% [markdown]
# Some more problems in this part have been left out. Will try them later. Moving on to next category.
#
# #### PART 4 - Date

# %%
# %%sql
# -- Produce a timestamp for 1 a.m. on the 31st of August 2012
#
# SELECT TIMESTAMP '2012-08-31 01:00:00';
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(datetime.datetime(2012, 8, 31, 1, 0),)]

# %%
# %%sql
# --alternate way
# SELECT CAST('2012-08-31 01:00:00' AS TIMESTAMP);
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(datetime.datetime(2012, 8, 31, 1, 0),)]

# %%
# %%sql
# --2 find result of subtracting the timestamp '2012-07-30 01:00:00' from timestamp '2012-08-31 01:00:00'
#
# SELECT TIMESTAMP '2012-08-31 01:00:00' - TIMESTAMP '2012-07-30 01:00:00' AS INTERVAL;
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(datetime.timedelta(32),)]

# %%
# %%sql
# ---3 generate a list of all the dates in October 2012
#
# SELECT GENERATE_SERIES(TIMESTAMP '2012-10-01', TIMESTAMP '2012-10-31', INTERVAL '1 DAY'); #Postgres specific solution
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 31 rows affected.
# [(datetime.datetime(2012, 10, 1, 0, 0),),
#  (datetime.datetime(2012, 10, 2, 0, 0),),
#  (datetime.datetime(2012, 10, 3, 0, 0),),
#  (datetime.datetime(2012, 10, 4, 0, 0),),
#  (datetime.datetime(2012, 10, 5, 0, 0),),
#  (datetime.datetime(2012, 10, 6, 0, 0),),
#  (datetime.datetime(2012, 10, 7, 0, 0),),
#  (datetime.datetime(2012, 10, 8, 0, 0),),
#  (datetime.datetime(2012, 10, 9, 0, 0),),
#  (datetime.datetime(2012, 10, 10, 0, 0),),
#  (datetime.datetime(2012, 10, 11, 0, 0),),
#  (datetime.datetime(2012, 10, 12, 0, 0),),
#  (datetime.datetime(2012, 10, 13, 0, 0),),
#  (datetime.datetime(2012, 10, 14, 0, 0),),
#  (datetime.datetime(2012, 10, 15, 0, 0),),
#  (datetime.datetime(2012, 10, 16, 0, 0),),
#  (datetime.datetime(2012, 10, 17, 0, 0),),
#  (datetime.datetime(2012, 10, 18, 0, 0),),
#  (datetime.datetime(2012, 10, 19, 0, 0),),
#  (datetime.datetime(2012, 10, 20, 0, 0),),
#  (datetime.datetime(2012, 10, 21, 0, 0),),
#  (datetime.datetime(2012, 10, 22, 0, 0),),
#  (datetime.datetime(2012, 10, 23, 0, 0),),
#  (datetime.datetime(2012, 10, 24, 0, 0),),
#  (datetime.datetime(2012, 10, 25, 0, 0),),
#  (datetime.datetime(2012, 10, 26, 0, 0),),
#  (datetime.datetime(2012, 10, 27, 0, 0),),
#  (datetime.datetime(2012, 10, 28, 0, 0),),
#  (datetime.datetime(2012, 10, 29, 0, 0),),
#  (datetime.datetime(2012, 10, 30, 0, 0),),
#  (datetime.datetime(2012, 10, 31, 0, 0),)]

# %%
# %%sql
# --4 Get the day of the month from timestamp '2012-08-31'
#
# SELECT EXTRACT (DAY FROM TIMESTAMP '2012-08-31');
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(31.0,)]

# %%
# %%sql
# --5 work out the number of days in each month of 2012
#
# SELECT EXTRACT (month FROM cal.month) AS month, (cal.month + interval '1 month') - cal.month AS length
# FROM (SELECT generate_series(TIMESTAMP '2012-01-01', TIMESTAMP '2012-12-01', interval '1 month') AS month) cal
# ORDER BY month;
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 12 rows affected.
# [(1.0, datetime.timedelta(31)),
#  (2.0, datetime.timedelta(29)),
#  (3.0, datetime.timedelta(31)),
#  (4.0, datetime.timedelta(30)),
#  (5.0, datetime.timedelta(31)),
#  (6.0, datetime.timedelta(30)),
#  (7.0, datetime.timedelta(31)),
#  (8.0, datetime.timedelta(31)),
#  (9.0, datetime.timedelta(30)),
#  (10.0, datetime.timedelta(31)),
#  (11.0, datetime.timedelta(30)),
#  (12.0, datetime.timedelta(31))]

# %%
# %%sql
# --6 given a timestamp '2012-02-11 01:00:00', find the number of days remaining in the month. include current day
#
# SELECT (DATE_TRUNC('month', ts.testts) + interval '1 month') -DATE_TRUNC('day', ts.testts) AS remaining
# FROM (SELECT TIMESTAMP '2012-02-11 01:00:00' AS testts) ts;
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 1 rows affected.
# [(datetime.timedelta(19),)]

# %% [markdown]
# Note the use of `DATE_TRUNC` function. Also note the way we've put the timestamp into a subquery. It mean you can give the timestamp a name, rather than having to list the literal repeatedly.

# %%
# %%sql
# --7 return list of start and end time of the last 10 bookings (ordered by the time at which they end, followed
# --by time they start) in the system
#
# SELECT starttime, starttime +slots*(interval '30 minutes') endtime FROM cd.bookings ORDER BY endtime DESC, starttime DESC
# LIMIT 10;
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 10 rows affected.
# [(datetime.datetime(2013, 1, 1, 15, 30), datetime.datetime(2013, 1, 1, 16, 0)),
#  (datetime.datetime(2012, 9, 30, 19, 30), datetime.datetime(2012, 9, 30, 20, 30)),
#  (datetime.datetime(2012, 9, 30, 19, 0), datetime.datetime(2012, 9, 30, 20, 30)),
#  (datetime.datetime(2012, 9, 30, 19, 30), datetime.datetime(2012, 9, 30, 20, 0)),
#  (datetime.datetime(2012, 9, 30, 19, 0), datetime.datetime(2012, 9, 30, 20, 0)),
#  (datetime.datetime(2012, 9, 30, 19, 0), datetime.datetime(2012, 9, 30, 20, 0)),
#  (datetime.datetime(2012, 9, 30, 18, 30), datetime.datetime(2012, 9, 30, 20, 0)),
#  (datetime.datetime(2012, 9, 30, 18, 30), datetime.datetime(2012, 9, 30, 20, 0)),
#  (datetime.datetime(2012, 9, 30, 19, 0), datetime.datetime(2012, 9, 30, 19, 30)),
#  (datetime.datetime(2012, 9, 30, 18, 30), datetime.datetime(2012, 9, 30, 19, 30))]

# %%
# %%sql
# -- 8 return a count of booking  for each month, sorted by month
#
# SELECT DATE_TRUNC('month', starttime) AS month, count(*) FROM cd.bookings
# GROUP BY month ORDER BY month;
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 4 rows affected.
# [(datetime.datetime(2012, 7, 1, 0, 0), 658),
#  (datetime.datetime(2012, 8, 1, 0, 0), 1472),
#  (datetime.datetime(2012, 9, 1, 0, 0), 1913),
#  (datetime.datetime(2013, 1, 1, 0, 0), 1)]

# %%
# %%sql
# --9 work out utilisation %age for each facility by month, sorted by name, rounded by 1 decimal point.
# --Opening time is '8:00 am', closing time '8:30 pm'
#
# SELECT name, month, round((100*slots)/cast(
# 25*(cast((month+interval '1 month') AS date) - cast (month AS date)) AS numeric),1) AS utilisation
# FROM (SELECT facs.name as name,
# DATE_TRUNC('month', starttime) AS
# month, sum(slots) AS slots
# FROM cd.bookings bks INNER JOIN cd.facilities facs
# ON bks.facid = facs.facid GROUP BY facs.facid, month) AS inn ORDER BY name, month;
# Out:
#  * postgres://postgres:***@localhost/exercises
#    postgres://postgres:***@localhost/postgres
# 28 rows affected.
# [('Badminton Court', datetime.datetime(2012, 7, 1, 0, 0), Decimal('23.2')),
#  ('Badminton Court', datetime.datetime(2012, 8, 1, 0, 0), Decimal('59.2')),
#  ('Badminton Court', datetime.datetime(2012, 9, 1, 0, 0), Decimal('76.0')),
#  ('Massage Room 1', datetime.datetime(2012, 7, 1, 0, 0), Decimal('34.1')),
#  ('Massage Room 1', datetime.datetime(2012, 8, 1, 0, 0), Decimal('63.5')),
#  ('Massage Room 1', datetime.datetime(2012, 9, 1, 0, 0), Decimal('86.4')),
#  ('Massage Room 2', datetime.datetime(2012, 7, 1, 0, 0), Decimal('3.1')),
#  ('Massage Room 2', datetime.datetime(2012, 8, 1, 0, 0), Decimal('10.6')),
#  ('Massage Room 2', datetime.datetime(2012, 9, 1, 0, 0), Decimal('16.3')),
#  ('Pool Table', datetime.datetime(2012, 7, 1, 0, 0), Decimal('15.1')),
#  ('Pool Table', datetime.datetime(2012, 8, 1, 0, 0), Decimal('41.5')),
#  ('Pool Table', datetime.datetime(2012, 9, 1, 0, 0), Decimal('62.8')),
#  ('Pool Table', datetime.datetime(2013, 1, 1, 0, 0), Decimal('0.1')),
#  ('Snooker Table', datetime.datetime(2012, 7, 1, 0, 0), Decimal('20.1')),
#  ('Snooker Table', datetime.datetime(2012, 8, 1, 0, 0), Decimal('42.1')),
#  ('Snooker Table', datetime.datetime(2012, 9, 1, 0, 0), Decimal('56.8')),
#  ('Squash Court', datetime.datetime(2012, 7, 1, 0, 0), Decimal('21.2')),
#  ('Squash Court', datetime.datetime(2012, 8, 1, 0, 0), Decimal('51.6')),
#  ('Squash Court', datetime.datetime(2012, 9, 1, 0, 0), Decimal('72.0')),
#  ('Table Tennis', datetime.datetime(2012, 7, 1, 0, 0), Decimal('13.4')),
#  ('Table Tennis', datetime.datetime(2012, 8, 1, 0, 0), Decimal('39.2')),
#  ('Table Tennis', datetime.datetime(2012, 9, 1, 0, 0), Decimal('56.3')),
#  ('Tennis Court 1', datetime.datetime(2012, 7, 1, 0, 0), Decimal('34.8')),
#  ('Tennis Court 1', datetime.datetime(2012, 8, 1, 0, 0), Decimal('59.2')),
#  ('Tennis Court 1', datetime.datetime(2012, 9, 1, 0, 0), Decimal('78.8')),
#  ('Tennis Court 2', datetime.datetime(2012, 7, 1, 0, 0), Decimal('26.7')),
#  ('Tennis Court 2', datetime.datetime(2012, 8, 1, 0, 0), Decimal('62.3')),
#  ('Tennis Court 2', datetime.datetime(2012, 9, 1, 0, 0), Decimal('78.4'))]
